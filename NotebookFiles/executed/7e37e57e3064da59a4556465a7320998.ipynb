# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
#Code for BigQuery
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_training.covid19_cases`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
covid19_cases_data = query_job.to_dataframe()
covid19_cases_data.head()
# Out:
#    week_number  start_date  county   fips  cases  deaths
# 0            9  2021-03-01  Marion  18097    664      23
# 1           12  2021-03-22  Marion  18097    623      11
# 2           19  2021-05-10  Marion  18097   1156       4
# 3           11  2021-03-15  Marion  18097    560      13
# 4            6  2021-02-08  Marion  18097   1542     219

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_training.unempoyment_data`
"""
query2="""
SELECT *
FROM `ironhacks-data.ironhacks_training.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unempolyment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In [6], line 3
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unempolyment_data = query_job.to_dataframe()
#       4 unemployment_data.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
#    1621     """Return a pandas DataFrame from a QueryJob
#    1622
#    1623     Args:
#    (...)
#    1685             :mod:`shapely` library cannot be imported.
#    1686     """
# -> 1687     query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688     return query_result.to_dataframe(
#    1689         bqstorage_client=bqstorage_client,
#    1690         dtypes=dtypes,
#    (...)
#    1693         geography_as_object=geography_as_object,
#    1694     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py:104, in wait_for_query(query_job, progress_bar_type, max_results)
#     100 progress_bar = get_progress_bar(
#     101     progress_bar_type, "Query is running", default_total, "query"
#     102 )
#     103 if progress_bar is None:
# --> 104     return query_job.result(max_results=max_results)
#     106 i = 0
#     107 while True:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1496     if retry_do_query is not None and job_retry is not None:
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#    1502     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1503         message=exc.message, location=self.location, job_id=self.job_id
#    1504     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1486     self._retry_do_query = retry_do_query
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#    1494 self._reload_query_results(retry=retry, timeout=timeout)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     725     self._begin(retry=retry, timeout=timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# NotFound: 404 Not found: Table ironhacks-data:ironhacks_training.unempoyment_data was not found in location US
#
# Location: US
# Job ID: ff44a6ee-3cfb-4c6d-832e-5462428d106a

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In [7], line 2
#       1 query_job = bigquery_client.query(query2)
# ----> 2 wage_data = query_job.to_dataframe()
#       3 wage_data.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
#    1621     """Return a pandas DataFrame from a QueryJob
#    1622
#    1623     Args:
#    (...)
#    1685             :mod:`shapely` library cannot be imported.
#    1686     """
# -> 1687     query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688     return query_result.to_dataframe(
#    1689         bqstorage_client=bqstorage_client,
#    1690         dtypes=dtypes,
#    (...)
#    1693         geography_as_object=geography_as_object,
#    1694     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py:104, in wait_for_query(query_job, progress_bar_type, max_results)
#     100 progress_bar = get_progress_bar(
#     101     progress_bar_type, "Query is running", default_total, "query"
#     102 )
#     103 if progress_bar is None:
# --> 104     return query_job.result(max_results=max_results)
#     106 i = 0
#     107 while True:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1496     if retry_do_query is not None and job_retry is not None:
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#    1502     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1503         message=exc.message, location=self.location, job_id=self.job_id
#    1504     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1486     self._retry_do_query = retry_do_query
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#    1494 self._reload_query_results(retry=retry, timeout=timeout)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     725     self._begin(retry=retry, timeout=timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# NotFound: 404 Not found: Table ironhacks-data:ironhacks_training.wage_data was not found in location US
#
# Location: US
# Job ID: acb99e8f-528e-44be-80f7-95ab69a1efbe

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_training.unemployment_data`
"""
query2="""
SELECT *
FROM `ironhacks-data.ironhacks_training.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unempolyment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In [9], line 3
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unempolyment_data = query_job.to_dataframe()
#       4 unemployment_data.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
#    1621     """Return a pandas DataFrame from a QueryJob
#    1622
#    1623     Args:
#    (...)
#    1685             :mod:`shapely` library cannot be imported.
#    1686     """
# -> 1687     query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688     return query_result.to_dataframe(
#    1689         bqstorage_client=bqstorage_client,
#    1690         dtypes=dtypes,
#    (...)
#    1693         geography_as_object=geography_as_object,
#    1694     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py:104, in wait_for_query(query_job, progress_bar_type, max_results)
#     100 progress_bar = get_progress_bar(
#     101     progress_bar_type, "Query is running", default_total, "query"
#     102 )
#     103 if progress_bar is None:
# --> 104     return query_job.result(max_results=max_results)
#     106 i = 0
#     107 while True:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1496     if retry_do_query is not None and job_retry is not None:
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#    1502     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1503         message=exc.message, location=self.location, job_id=self.job_id
#    1504     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1486     self._retry_do_query = retry_do_query
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#    1494 self._reload_query_results(retry=retry, timeout=timeout)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     725     self._begin(retry=retry, timeout=timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# NotFound: 404 Not found: Table ironhacks-data:ironhacks_training.unemployment_data was not found in location US
#
# Location: US
# Job ID: 206b0147-ebfd-45c3-9379-0330262fb083

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In [10], line 2
#       1 query_job = bigquery_client.query(query2)
# ----> 2 wage_data = query_job.to_dataframe()
#       3 wage_data.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
#    1621     """Return a pandas DataFrame from a QueryJob
#    1622
#    1623     Args:
#    (...)
#    1685             :mod:`shapely` library cannot be imported.
#    1686     """
# -> 1687     query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688     return query_result.to_dataframe(
#    1689         bqstorage_client=bqstorage_client,
#    1690         dtypes=dtypes,
#    (...)
#    1693         geography_as_object=geography_as_object,
#    1694     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py:104, in wait_for_query(query_job, progress_bar_type, max_results)
#     100 progress_bar = get_progress_bar(
#     101     progress_bar_type, "Query is running", default_total, "query"
#     102 )
#     103 if progress_bar is None:
# --> 104     return query_job.result(max_results=max_results)
#     106 i = 0
#     107 while True:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1496     if retry_do_query is not None and job_retry is not None:
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#    1502     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1503         message=exc.message, location=self.location, job_id=self.job_id
#    1504     )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1486     self._retry_do_query = retry_do_query
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#    1494 self._reload_query_results(retry=retry, timeout=timeout)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     725     self._begin(retry=retry, timeout=timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# NotFound: 404 Not found: Table ironhacks-data:ironhacks_training.wage_data was not found in location US
#
# Location: US
# Job ID: 7f328d40-877c-4100-8e94-74933c3f91f1

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2="""
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unempolyment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 4
#       2 query_job = bigquery_client.query(query)
#       3 unempolyment_data = query_job.to_dataframe()
# ----> 4 unemployment_data.head()
#
# NameError: name 'unemployment_data' is not defined

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unempolyment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 4
#       2 query_job = bigquery_client.query(query)
#       3 unempolyment_data = query_job.to_dataframe()
# ----> 4 unemployment_data.head()
#
# NameError: name 'unemployment_data' is not defined

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unempolyment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 4
#       2 query_job = bigquery_client.query(query)
#       3 unempolyment_data = query_job.to_dataframe()
# ----> 4 unemployment_data.head()
#
# NameError: name 'unemployment_data' is not defined

# %%
query_job2 = bigquery_client.query(query2)
wage_data = query_job2.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
#Testing bigquery
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
# 2  6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3  46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4  37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
# 2  11500  Census Tract 115, Lake County, Indiana            39
# 3  20700  Census Tract 207, Lake County, Indiana            14
# 4  21900  Census Tract 219, Lake County, Indiana           155
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>                 14  ...           <NA>
# 1                0             <NA>                108  ...             76
# 2                0             <NA>               <NA>  ...           <NA>
# 3                0             <NA>               <NA>  ...           <NA>
# 4                0             <NA>                 69  ...             90
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0          11
# 1           35         0               0          0        <NA>
# 2         <NA>         0               0          0          39
# 3         <NA>         0               0       <NA>          10
# 4           65         0               0          0         135
#
#    race_noanswer  race_hawaiiannative  race_other  race_white
# 0              0                    0        <NA>        <NA>
# 1           <NA>                    0           0           0
# 2              0                    0           0           0
# 3              0                    0        <NA>        <NA>
# 4           <NA>                 <NA>        <NA>        <NA>
#
# [5 rows x 25 columns]

# %%
query_job2 = bigquery_client.query(query2)
wage_data = query_job2.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
#Query 
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
#Query Unemployment data
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
# 2  6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3  46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4  37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
# 2  11500  Census Tract 115, Lake County, Indiana            39
# 3  20700  Census Tract 207, Lake County, Indiana            14
# 4  21900  Census Tract 219, Lake County, Indiana           155
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>                 14  ...           <NA>
# 1                0             <NA>                108  ...             76
# 2                0             <NA>               <NA>  ...           <NA>
# 3                0             <NA>               <NA>  ...           <NA>
# 4                0             <NA>                 69  ...             90
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0          11
# 1           35         0               0          0        <NA>
# 2         <NA>         0               0          0          39
# 3         <NA>         0               0       <NA>          10
# 4           65         0               0          0         135
#
#    race_noanswer  race_hawaiiannative  race_other  race_white
# 0              0                    0        <NA>        <NA>
# 1           <NA>                    0           0           0
# 2              0                    0           0           0
# 3              0                    0        <NA>        <NA>
# 4           <NA>                 <NA>        <NA>        <NA>
#
# [5 rows x 25 columns]

# %%
#Query Wage Data
query2= """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
#Query Unemployment data
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
order by week_number
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.head()
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1  14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2  f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3  f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4  778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
#
#     tract                                      tract_name  total_claims  \
# 0  950500     Census Tract 9505, Lawrence County, Indiana            10
# 1  110506  Census Tract 1105.06, Hamilton County, Indiana            39
# 2     900           Census Tract 9, Allen County, Indiana            10
# 3   10600          Census Tract 106, Vigo County, Indiana            35
# 4   11200          Census Tract 112, Vigo County, Indiana            37
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>               <NA>  ...           <NA>
# 1             <NA>                0               <NA>  ...           <NA>
# 2                0                0               <NA>  ...           <NA>
# 3                0             <NA>                 21  ...           <NA>
# 4                0             <NA>                 24  ...             26
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0        <NA>
# 1         <NA>         0               0          0        <NA>
# 2         <NA>         0               0          0        <NA>
# 3         <NA>         0               0          0           0
# 4           11         0               0          0        <NA>
#
#    race_noanswer  race_hawaiiannative  race_other  race_white
# 0              0                    0           0        <NA>
# 1           <NA>                    0        <NA>          28
# 2              0                    0        <NA>        <NA>
# 3           <NA>                    0        <NA>          32
# 4           <NA>                    0        <NA>        <NA>
#
# [5 rows x 25 columns]

# %%
#Query Wage Data
query2= """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
order by tract
"""

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  6ac331ecae4b7e4dd2750893612331f9       18053    100
# 1  16b9d35c6d253c30527eb2de8d2d1bb9       18141    100
# 2  585f8731c2255d6b3f817a31180848b9       18177    200
# 3  c676fe3aef9660b4e225ac44d2e1174b       18039    200
# 4  ce64452a172b006bd45b3c1f147c88c1       18053    200
#
#                                    tract_name  average_wage
# 0       Census Tract 1, Grant County, Indiana   8901.400000
# 1  Census Tract 1, St. Joseph County, Indiana   7361.100000
# 2       Census Tract 2, Wayne County, Indiana   6612.000000
# 3     Census Tract 2, Elkhart County, Indiana  15600.391304
# 4       Census Tract 2, Grant County, Indiana  10198.000000

# %%
#Query Wage Data
query2= """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
order by tract
"""

# %%
query_job = bigquery_client.query(query2)
wage_data = query_job.to_dataframe()
wage_data
# Out:
#                                 uu_id  countyfips   tract  \
# 0    6ac331ecae4b7e4dd2750893612331f9       18053     100
# 1    16b9d35c6d253c30527eb2de8d2d1bb9       18141     100
# 2    585f8731c2255d6b3f817a31180848b9       18177     200
# 3    c676fe3aef9660b4e225ac44d2e1174b       18039     200
# 4    ce64452a172b006bd45b3c1f147c88c1       18053     200
# ..                                ...         ...     ...
# 520  fca0703f480d461a24d0b68fd994815e       18113  972400
# 521  0aed17ab54d56c6651d331418e8db6be       18009  975300
# 522  cfeb7a55105a6e277ebef7dc3df83ffc       18065  975800
# 523  cd572640b6e423db8fd7ad50ef0b4473       18065  976000
# 524  19c0ba2728a6971ff9c1301f3bf17f59       18065  976400
#
#                                        tract_name  average_wage
# 0           Census Tract 1, Grant County, Indiana   8901.400000
# 1      Census Tract 1, St. Joseph County, Indiana   7361.100000
# 2           Census Tract 2, Wayne County, Indiana   6612.000000
# 3         Census Tract 2, Elkhart County, Indiana  15600.391304
# 4           Census Tract 2, Grant County, Indiana  10198.000000
# ..                                            ...           ...
# 520      Census Tract 9724, Noble County, Indiana  18390.428571
# 521  Census Tract 9753, Blackford County, Indiana   7689.800000
# 522      Census Tract 9758, Henry County, Indiana   8230.222222
# 523      Census Tract 9760, Henry County, Indiana  10188.500000
# 524      Census Tract 9764, Henry County, Indiana  14287.142857
#
# [525 rows x 5 columns]
