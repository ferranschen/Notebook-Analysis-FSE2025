# %%
import csv
import pandas as pd
import numpy as np
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt  
import db_dtypes

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 #QUERY DATA
# ----> 2 query_job = bigquery_client.query(query)
#       3 print(query_job)
#       4 unemp = query_job.to_dataframe()
#
# NameError: name 'bigquery_client' is not defined

# %%
import os
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
# Out:
# QueryJob<project=ironhacks-data, location=US, id=c343ebbf-5790-464f-af0e-55757ef532e0>

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
head(unemp, n=3)
# Out:
# QueryJob<project=ironhacks-data, location=US, id=11d68282-40a0-4ae0-8618-4b3b2fa66777>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 5
#       3 print(query_job)
#       4 unemp = query_job.to_dataframe()
# ----> 5 head(unemp, n=3)
#
# NameError: name 'head' is not defined

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
unemp.head(2)
# Out:
# QueryJob<project=ironhacks-data, location=US, id=3739b5b7-a3bf-457a-9594-9d9b5f0d944e>
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>                 14  ...           <NA>
# 1                0             <NA>                108  ...             76
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0          11
# 1           35         0               0          0        <NA>
#
# ...

# %%
unemp.loc[unemp['tract_name'] == "Allen County"]
# Out:
# Empty DataFrame
# Columns: [uu_id, timeperiod, week_number, countyfips, tract, tract_name, total_claims, edu_8th_or_less, edu_grades_9_11, edu_hs_grad_equiv, edu_post_hs, edu_unknown, top_category_employer1, top_category_employer2, top_category_employer3, gender_female, gender_male, gender_na, race_amerindian, race_asian, race_black, race_noanswer, race_hawaiiannative, race_other, race_white]
# Index: []
#
# [0 rows x 25 columns]

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 9, Allen County, Indiana"]
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 186    f013068de98db1470bd986137a0c6d23    20220212            7       18003
# 187    f013068de98db1470bd986137a0c6d23    20220827           35       18003
# 188    f013068de98db1470bd986137a0c6d23    20220312           11       18003
# 189    f013068de98db1470bd986137a0c6d23    20220205            6       18003
# 190    f013068de98db1470bd986137a0c6d23    20220305           10       18003
# 191    f013068de98db1470bd986137a0c6d23    20220827           35       18003
# 192    f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3976   f013068de98db1470bd986137a0c6d23    20220319           12       18003
# 7351   f013068de98db1470bd986137a0c6d23    20220129            5       18003
# 9957   f013068de98db1470bd986137a0c6d23    20220528           22       18003
# ...

# %%
unemp['tract_name'].value_counts()['tract_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tract_name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(unemp['tract_name'].value_counts())
# Out:
# Census Tract 424.02, Lake County, Indiana         42
# Census Tract 3103.05, Marion County, Indiana      42
# Census Tract 26, Elkhart County, Indiana          42
# Census Tract 1105.06, Hamilton County, Indiana    42
# Census Tract 15.01, Elkhart County, Indiana       42
#                                                   ..
# Census Tract 111, Madison County, Indiana          6
# Census Tract 1102.01, Hamilton County, Indiana     6
# Census Tract 9598, Carroll County, Indiana         6
# Census Tract 9704.02, LaGrange County, Indiana     5
# Census Tract 204, Marshall County, Indiana         4
# Name: tract_name, Length: 525, dtype: int64

# %%
print(sort(unemp['tract_name'].value_counts()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 print(sort(unemp['tract_name'].value_counts()))
#
# NameError: name 'sort' is not defined

# %%
print(unemp['tract_name'].value_counts())
# Out:
# Census Tract 424.02, Lake County, Indiana         42
# Census Tract 3103.05, Marion County, Indiana      42
# Census Tract 26, Elkhart County, Indiana          42
# Census Tract 1105.06, Hamilton County, Indiana    42
# Census Tract 15.01, Elkhart County, Indiana       42
#                                                   ..
# Census Tract 111, Madison County, Indiana          6
# Census Tract 1102.01, Hamilton County, Indiana     6
# Census Tract 9598, Carroll County, Indiana         6
# Census Tract 9704.02, LaGrange County, Indiana     5
# Census Tract 204, Marshall County, Indiana         4
# Name: tract_name, Length: 525, dtype: int64

# %%
print(unemp.tail(unemp['tract_name'].value_counts()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 print(unemp.tail(unemp['tract_name'].value_counts()))
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py:5622, in NDFrame.tail(self, n)
#    5549 @final
#    5550 def tail(self: NDFrameT, n: int = 5) -> NDFrameT:
#    5551     """
#    5552     Return the last `n` rows.
#    5553
#    (...)
#    5620     8   zebra
#    5621     """
# -> 5622     if n == 0:
#    5623         return self.iloc[0:0]
#    5624     return self.iloc[-n:]
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
print((unemp['tract_name'].value_counts())
# Out:
#   Cell In [18], line 1
#     print((unemp['tract_name'].value_counts())
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 7, Allen County, Indiana"]
# Out:
# Empty DataFrame
# Columns: [uu_id, timeperiod, week_number, countyfips, tract, tract_name, total_claims, edu_8th_or_less, edu_grades_9_11, edu_hs_grad_equiv, edu_post_hs, edu_unknown, top_category_employer1, top_category_employer2, top_category_employer3, gender_female, gender_male, gender_na, race_amerindian, race_asian, race_black, race_noanswer, race_hawaiiannative, race_other, race_white]
# Index: []
#
# [0 rows x 25 columns]

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 8, Allen County, Indiana"]
# Out:
# Empty DataFrame
# Columns: [uu_id, timeperiod, week_number, countyfips, tract, tract_name, total_claims, edu_8th_or_less, edu_grades_9_11, edu_hs_grad_equiv, edu_post_hs, edu_unknown, top_category_employer1, top_category_employer2, top_category_employer3, gender_female, gender_male, gender_na, race_amerindian, race_asian, race_black, race_noanswer, race_hawaiiannative, race_other, race_white]
# Index: []
#
# [0 rows x 25 columns]

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 43, Allen County, Indiana"]
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 406    5b266c11201654ddb90d1a80cf294645    20220115            3       18003
# 407    5b266c11201654ddb90d1a80cf294645    20220319           12       18003
# 408    5b266c11201654ddb90d1a80cf294645    20220129            5       18003
# 409    5b266c11201654ddb90d1a80cf294645    20220101            1       18003
# 2129   5b266c11201654ddb90d1a80cf294645    20220430           18       18003
# 2561   5b266c11201654ddb90d1a80cf294645    20220326           13       18003
# 2562   5b266c11201654ddb90d1a80cf294645    20220312           11       18003
# 2563   5b266c11201654ddb90d1a80cf294645    20220305           10       18003
# 2564   5b266c11201654ddb90d1a80cf294645    20220226            9       18003
# 2565   5b266c11201654ddb90d1a80cf294645    20220212            7       18003
# 4302   5b266c11201654ddb90d1a80cf294645    20220219            8       18003
# ...

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 13, Allen County, Indiana"]
# Out:
# Empty DataFrame
# Columns: [uu_id, timeperiod, week_number, countyfips, tract, tract_name, total_claims, edu_8th_or_less, edu_grades_9_11, edu_hs_grad_equiv, edu_post_hs, edu_unknown, top_category_employer1, top_category_employer2, top_category_employer3, gender_female, gender_male, gender_na, race_amerindian, race_asian, race_black, race_noanswer, race_hawaiiannative, race_other, race_white]
# Index: []
#
# [0 rows x 25 columns]

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 43, Allen County, Indiana"]
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 406    5b266c11201654ddb90d1a80cf294645    20220115            3       18003
# 407    5b266c11201654ddb90d1a80cf294645    20220319           12       18003
# 408    5b266c11201654ddb90d1a80cf294645    20220129            5       18003
# 409    5b266c11201654ddb90d1a80cf294645    20220101            1       18003
# 2129   5b266c11201654ddb90d1a80cf294645    20220430           18       18003
# 2561   5b266c11201654ddb90d1a80cf294645    20220326           13       18003
# 2562   5b266c11201654ddb90d1a80cf294645    20220312           11       18003
# 2563   5b266c11201654ddb90d1a80cf294645    20220305           10       18003
# 2564   5b266c11201654ddb90d1a80cf294645    20220226            9       18003
# 2565   5b266c11201654ddb90d1a80cf294645    20220212            7       18003
# 4302   5b266c11201654ddb90d1a80cf294645    20220219            8       18003
# ...

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 43, Allen County, Indiana"].head
# Out:
# <bound method NDFrame.head of                                   uu_id  timeperiod  week_number  countyfips  \
# 406    5b266c11201654ddb90d1a80cf294645    20220115            3       18003
# 407    5b266c11201654ddb90d1a80cf294645    20220319           12       18003
# 408    5b266c11201654ddb90d1a80cf294645    20220129            5       18003
# 409    5b266c11201654ddb90d1a80cf294645    20220101            1       18003
# 2129   5b266c11201654ddb90d1a80cf294645    20220430           18       18003
# 2561   5b266c11201654ddb90d1a80cf294645    20220326           13       18003
# 2562   5b266c11201654ddb90d1a80cf294645    20220312           11       18003
# 2563   5b266c11201654ddb90d1a80cf294645    20220305           10       18003
# 2564   5b266c11201654ddb90d1a80cf294645    20220226            9       18003
# 2565   5b266c11201654ddb90d1a80cf294645    20220212            7       18003
# 4302   5b266c11201654ddb90d1a80cf294645    20220219            8       18003
# ...

# %%
unemp.loc[unemp['tract_name'] == "Census Tract 43, Allen County, Indiana"]
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 406    5b266c11201654ddb90d1a80cf294645    20220115            3       18003
# 407    5b266c11201654ddb90d1a80cf294645    20220319           12       18003
# 408    5b266c11201654ddb90d1a80cf294645    20220129            5       18003
# 409    5b266c11201654ddb90d1a80cf294645    20220101            1       18003
# 2129   5b266c11201654ddb90d1a80cf294645    20220430           18       18003
# 2561   5b266c11201654ddb90d1a80cf294645    20220326           13       18003
# 2562   5b266c11201654ddb90d1a80cf294645    20220312           11       18003
# 2563   5b266c11201654ddb90d1a80cf294645    20220305           10       18003
# 2564   5b266c11201654ddb90d1a80cf294645    20220226            9       18003
# 2565   5b266c11201654ddb90d1a80cf294645    20220212            7       18003
# 4302   5b266c11201654ddb90d1a80cf294645    20220219            8       18003
# ...

# %%
X = data['total_claims'].values.reshape(-1,1)
y = data['gender_male'].values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 X = data['total_claims'].values.reshape(-1,1)
#       2 y = data['gender_male'].values.reshape(-1,1)
#
# NameError: name 'data' is not defined

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
X = unemp['total_claims'].values.reshape(-1,1)
Y = unemp['gender_male'].values.reshape(-1,1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 X_train.head()
#
# AttributeError: 'IntegerArray' object has no attribute 'head'

# %%
X_train.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 X_train.head
#
# AttributeError: 'IntegerArray' object has no attribute 'head'

# %%
print(X_train)
# Out:
# <IntegerArray>
# [
# [65],
# [23],
# [18],
# [15],
# [12],
# [22],
# [23],
# [30],
# [22],
# [22],
# [102],
# [10],
# [54],
# [16],
# [43],
# [19],
# [36],
# [19],
# [17],
# [33],
# [16],
# [33],
# [50],
# [22],
# [26],
# [10],
# [40],
# [30],
# [12],
# [20],
# [16],
# [36],
# [18],
# [52],
# [28],
# [10],
# [16],
# [43],
# [38],
# [18],
# [20],
# [14],
# [29],
# [36],
# [30],
# [10],
# [24],
# [51],
# [12],
# [14],
# [16],
# [26],
# [82],
# [13],
# [13],
# [24],
# [19],
# [47],
# [22],
# [10],
# [23],
# [39],
# [42],
# [14],
# [28],
# [11],
# [14],
# [22],
# [10],
# [15],
# [28],
# [16],
# [18],
# [16],
# [19],
# [26],
# [15],
# [13],
# [26],
# [12],
# [14],
# [18],
# [32],
# [12],
# [20],
# [15],
# [13],
# [21],
# [26],
# [39],
# [12],
# [18],
# [11],
# [13],
# [11],
# [24],
# [11],
# [16],
# [19],
# [17],
# [30],
# [17],
# [11],
# [46],
# [15],
# [46],
# [15],
# [10],
# [38],
# [31],
# [13],
# [11],
# [17],
# [61],
# [49],
# [11],
# [16],
# [24],
# [11],
# [12],
# [24],
# [14],
# ...

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [33], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# NameError: name 'y_train' is not defined

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, Y_train)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [36], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, Y_train)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
X.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 X.head
#
# AttributeError: 'IntegerArray' object has no attribute 'head'

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [41], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
#To retrieve the intercept:
print(regressor.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [42], line 2
#       1 #To retrieve the intercept:
# ----> 2 print(regressor.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
#For retrieving the slope:
print(regressor.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [43], line 2
#       1 #For retrieving the slope:
# ----> 2 print(regressor.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [48], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
print(X_test)
# Out:
# <IntegerArray>
# [
# [45],
# [10],
# [16],
# [13],
# [44],
# [14],
# [46],
# [16],
# [25],
# [14],
# [48],
# [56],
# [35],
# [19],
# [16],
# [32],
# [28],
# [24],
# [16],
# [20],
# [18],
# [18],
# [15],
# [12],
# [21],
# [10],
# [18],
# [11],
# [20],
# [10],
# [16],
# [19],
# [10],
# [46],
# [10],
# [13],
# [17],
# [16],
# [21],
# [10],
# [11],
# [21],
# [13],
# [35],
# [29],
# [13],
# [30],
# [15],
# [19],
# [10],
# [27],
# [14],
# [16],
# [10],
# [22],
# [27],
# [10],
# [14],
# [35],
# [49],
# [19],
# [10],
# [11],
# [18],
# [14],
# [16],
# [14],
# [11],
# [54],
# [12],
# [10],
# [27],
# [21],
# [12],
# [26],
# [14],
# [11],
# [41],
# [21],
# [29],
# [44],
# [20],
# [24],
# [36],
# [10],
# [24],
# [11],
# [28],
# [26],
# [26],
# [14],
# [14],
# [19],
# [12],
# [11],
# [48],
# [20],
# [13],
# [16],
# [17],
# [29],
# [20],
# [19],
# [29],
# [13],
# [37],
# [56],
# [18],
# [14],
# [26],
# [12],
# [16],
# [22],
# [19],
# [13],
# [22],
# [19],
# [24],
# [16],
# [33],
# [53],
# [12],
# ...

# %%
print(y)
# Out:
# <IntegerArray>
# [
# [<NA>],
# [35],
# [<NA>],
# [<NA>],
# [65],
# [10],
# [10],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [39],
# [<NA>],
# [<NA>],
# [39],
# [46],
# [46],
# [<NA>],
# [34],
# [<NA>],
# [34],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [0],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [17],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [13],
# [15],
# [<NA>],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [32],
# [32],
# [15],
# [<NA>],
# [<NA>],
# [17],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [35],
# [<NA>],
# [<NA>],
# [22],
# [<NA>],
# [11],
# [10],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [52],
# [<NA>],
# [30],
# [<NA>],
# [<NA>],
# ...

# %%
print(y)
# Out:
# <IntegerArray>
# [
# [<NA>],
# [35],
# [<NA>],
# [<NA>],
# [65],
# [10],
# [10],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [39],
# [<NA>],
# [<NA>],
# [39],
# [46],
# [46],
# [<NA>],
# [34],
# [<NA>],
# [34],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [0],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [17],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [13],
# [15],
# [<NA>],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [32],
# [32],
# [15],
# [<NA>],
# [<NA>],
# [17],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [35],
# [<NA>],
# [<NA>],
# [22],
# [<NA>],
# [11],
# [10],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [52],
# [<NA>],
# [30],
# [<NA>],
# [<NA>],
# ...

# %%
unemp = unemp[unemp['tract'] == 4300]

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
print(y)
# Out:
# <IntegerArray>
# [
# [<NA>],
# [<NA>],
# [13],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [33],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>]
# ]
# Shape: (19, 1), dtype: Int64

# %%
X = np.array(X)
y = np.array(y)

# %%
print(y)
# Out:
# [[<NA>]
#  [<NA>]
#  [13]
#  [12]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [33]
#  [12]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train)
# Out:
# [[22]
#  [18]
#  [10]
#  [17]
#  [28]
#  [11]
#  [44]
#  [11]
#  [12]
#  [10]
#  [16]
#  [23]
#  [16]
#  [11]
#  [12]]

# %%
#Trains Algorithim
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [59], line 3
#       1 #Trains Algorithim
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
print(y_train)
# Out:
# [[12]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [13]
#  [<NA>]
#  [33]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [<NA>]
#  [12]
#  [<NA>]
#  [<NA>]
#  [<NA>]]

# %%
unemp = unemp[unemp['tract'] == 4300].dropNA()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 unemp = unemp[unemp['tract'] == 4300].dropNA()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropNA'

# %%
unemp = unemp[unemp['tract'] == 4300].dropna()

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
print(y)
# Out:
# <IntegerArray>
# [
#
# ]
# Shape: (0, 1), dtype: Int64

# %%
unemp = unemp[unemp['tract'] == 4300]

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
print(y)
# Out:
# <IntegerArray>
# [
#
# ]
# Shape: (0, 1), dtype: Int64

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
unemp.head(2)
# Out:
# QueryJob<project=ironhacks-data, location=US, id=13facea5-48ea-4cde-aaa6-bc37d4c9b22d>
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>                 14  ...           <NA>
# 1                0             <NA>                108  ...             76
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0          11
# 1           35         0               0          0        <NA>
#
# ...

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
# Out:
# QueryJob<project=ironhacks-data, location=US, id=5f069ab7-7cb1-49ba-b080-657f61fd82ad>

# %%
unemp = unemp[unemp['tract'] == 4300]

# %%
X = unemp['total_claims'].values.reshape(-1,1)
y = unemp['gender_male'].values.reshape(-1,1)

# %%
print(y)
# Out:
# <IntegerArray>
# [
# [<NA>],
# [<NA>],
# [13],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>],
# [33],
# [12],
# [<NA>],
# [<NA>],
# [<NA>],
# [<NA>]
# ]
# Shape: (19, 1), dtype: Int64

# %%
X = np.array(X)
y = np.array(y)

# %%
unemp.groupby(['tract']).Tract.value_counts().nlargest(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [76], line 1
# ----> 1 unemp.groupby(['tract']).Tract.value_counts().nlargest(5)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:981, in GroupBy.__getattr__(self, attr)
#     978 if attr in self.obj:
#     979     return self[attr]
# --> 981 raise AttributeError(
#     982     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     983 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Tract'

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
#QUERY DATA
query_job = bigquery_client.query(query)
print(query_job)
unemp = query_job.to_dataframe()
# Out:
# QueryJob<project=ironhacks-data, location=US, id=b7749c6c-084f-4772-b924-ead818b86081>

# %%
unemp.groupby(['tract']).Tract.value_counts().nlargest(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [79], line 1
# ----> 1 unemp.groupby(['tract']).Tract.value_counts().nlargest(5)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:981, in GroupBy.__getattr__(self, attr)
#     978 if attr in self.obj:
#     979     return self[attr]
# --> 981 raise AttributeError(
#     982     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     983 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Tract'
