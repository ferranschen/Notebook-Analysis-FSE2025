# %%
get_ipython().system('pip install db-dtypes')
# Out:
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/anaconda3/lib/python3.9/site-packages)

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT *
FROM `ironhacks-data:ironhacks_competition.unemployment_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment = query_job.to_dataframe()
unemployment.head()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In [5], line 3
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment = query_job.to_dataframe()
#       4 unemployment.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
#    1621     """Return a pandas DataFrame from a QueryJob
#    1622
#    1623     Args:
#    (...)
#    1685             :mod:`shapely` library cannot be imported.
#    1686     """
# ...

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_training.covid19_cases`
"""

# %%
query_job = bigquery_client.query(query)
covid19_cases_data = query_job.to_dataframe()
print(covid19_cases_data)
# Out:
#     week_number  start_date      county   fips  cases  deaths
# 0             9  2021-03-01      Marion  18097    664      23
# 1            12  2021-03-22      Marion  18097    623      11
# 2            19  2021-05-10      Marion  18097   1156       4
# 3            11  2021-03-15      Marion  18097    560      13
# 4             6  2021-02-08      Marion  18097   1542     219
# 5            14  2021-04-05      Marion  18097    849       6
# 6             1  2021-01-04      Marion  18097   4714      77
# 7            18  2021-05-03      Marion  18097   1201       9
# 8             5  2021-02-01      Marion  18097   1972      24
# 9            15  2021-04-12      Marion  18097   1278       6
# 10           17  2021-04-26      Marion  18097    933       6
# 11            8  2021-02-22      Marion  18097    743      15
# 12           16  2021-04-19      Marion  18097   1111      17
# 13           23  2021-06-07      Marion  18097    819       3
# ...

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_training.covid19_cases`
"""

# %%
query_job = bigquery_client.query(query)
covid19_cases_data = query_job.to_dataframe()
covid19_cases_data.head()
# Out:
#    week_number  start_date  county   fips  cases  deaths
# 0            9  2021-03-01  Marion  18097    664      23
# 1           12  2021-03-22  Marion  18097    623      11
# 2           19  2021-05-10  Marion  18097   1156       4
# 3           11  2021-03-15  Marion  18097    560      13
# 4            6  2021-02-08  Marion  18097   1542     219

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
query_job = bigquery_client.query(query)
covid19_cases_data = query_job.to_dataframe()
covid19_cases_data.head()
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
# 2  6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3  46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4  37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
# 2  11500  Census Tract 115, Lake County, Indiana            39
# 3  20700  Census Tract 207, Lake County, Indiana            14
# 4  21900  Census Tract 219, Lake County, Indiana           155
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# ...

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
query_job = bigquery_client.query(query)
unem = query_job.to_dataframe()
unem.head()
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1  21957d5517323845818d87623589e1ba    20220319           12       18089
# 2  6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3  46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4  37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
#
#    tract                              tract_name  total_claims  \
# 0    900   Census Tract 9, Allen County, Indiana            22
# 1  10400  Census Tract 104, Lake County, Indiana           111
# 2  11500  Census Tract 115, Lake County, Indiana            39
# 3  20700  Census Tract 207, Lake County, Indiana            14
# 4  21900  Census Tract 219, Lake County, Indiana           155
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# ...

# %%
query1 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.prediction_list`
"""

# %%
query_job1 = bigquery_client.query(query1)
query_job2 = bigquery_client.query(query2)
query_job3 = bigquery_client.query(query3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 3
#       1 query_job1 = bigquery_client.query(query1)
#       2 query_job2 = bigquery_client.query(query2)
# ----> 3 query_job3 = bigquery_client.query(query3)
#
# NameError: name 'query3' is not defined

# %%
unemployment = query_job1.to_dataframe()
wage = query_job2.to_dataframe()
pred = query_job3.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 3
#       1 unemployment = query_job1.to_dataframe()
#       2 wage = query_job2.to_dataframe()
# ----> 3 pred = query_job3.to_dataframe()
#
# NameError: name 'query_job3' is not defined

# %%
query1 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""
query3 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.prediction_list`
"""

# %%
query_job1 = bigquery_client.query(query1)
query_job2 = bigquery_client.query(query2)
query_job3 = bigquery_client.query(query3)

# %%
unemployment = query_job1.to_dataframe()
wage = query_job2.to_dataframe()
pred = query_job3.to_dataframe()

# %%
wage.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
wage.columns
# Out:
# Index(['uu_id', 'countyfips', 'tract', 'tract_name', 'average_wage'], dtype='object')

# %%
pred.head()
# Out:
#                               uu_id  week_number
# 0  5bf51fc2e162d6faf9e3cf79e4198378           44
# 1  420b44cc7e3f55d738df565421e59941           44
# 2  e39c66ecceec76ee8f9f811fa4a2d246           44
# 3  a90462cd11ae4e43144239bf7c4828a4           44
# 4  8b20a6749088c7ff1237983076ebfeaa           44

# %%
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
get_ipython().system('python3 -m pip install xgboost')
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.6 MB ? eta -:--:--
#      ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.6 MB 4.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━ 1.0/1.6 MB 8.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.1 MB/s eta 0:00:00
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
get_ipython().system('python3 -m pip install xgboost')
get_ipython().system('python3 -m pip install sklearn')
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
get_ipython().system('python3 -m pip install xgboost')
get_ipython().system('python3 -m pip install sklearn')
get_ipython().system('python3 -m pip install scipy')
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
wage.head()
# Out:
#                               uu_id  countyfips  tract  \
# 0  585f8731c2255d6b3f817a31180848b9       18177    200
# 1  8c9d2aa90948679972a9382aadcc6001       18177    900
# 2  0f3d45341a5b113b813ffb7be7f58bab       18183  50300
# 3  fb55464f8e34af6d750d06968bf719b8       18183  50400
# 4  983badfd7b568728e39a2344a9006078       18001  30200
#
#                                   tract_name  average_wage
# 0      Census Tract 2, Wayne County, Indiana   6612.000000
# 1      Census Tract 9, Wayne County, Indiana   9883.250000
# 2  Census Tract 503, Whitley County, Indiana  13992.250000
# 3  Census Tract 504, Whitley County, Indiana  13613.500000
# 4    Census Tract 302, Adams County, Indiana  11816.666667

# %%
unemployment.columns
# Out:
# Index(['uu_id', 'timeperiod', 'week_number', 'countyfips', 'tract',
#        'tract_name', 'total_claims', 'edu_8th_or_less', 'edu_grades_9_11',
#        'edu_hs_grad_equiv', 'edu_post_hs', 'edu_unknown',
#        'top_category_employer1', 'top_category_employer2',
#        'top_category_employer3', 'gender_female', 'gender_male', 'gender_na',
#        'race_amerindian', 'race_asian', 'race_black', 'race_noanswer',
#        'race_hawaiiannative', 'race_other', 'race_white'],
#       dtype='object')

# %%
query3 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.wage.uu_id
"""

# %%
query1 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""
query2 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""
query3 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.prediction_list`
"""

# %%
query_job1 = bigquery_client.query(query1)
query_job2 = bigquery_client.query(query2)
query_job3 = bigquery_client.query(query3)

# %%
unemployment = query_job1.to_dataframe()
wage = query_job2.to_dataframe()
pred = query_job3.to_dataframe()

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.wage.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In [33], line 8
#       1 query4 = """
#       2 SELECT *
#       3 FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
#       4 inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
#       5 on wage.uu_id = unem.wage.uu_id
#       6 """
#       7 query_job4 = bigquery_client.query(query4)
# ----> 8 data = query_job4.to_dataframe()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
# ...

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.wage.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In [34], line 8
#       1 query4 = """
#       2 SELECT *
#       3 FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
#       4 inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
#       5 on wage.uu_id = unem.wage.uu_id
#       6 """
#       7 query_job4 = bigquery_client.query(query4)
# ----> 8 data = query_job4.to_dataframe()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
# ...

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
data
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1      21957d5517323845818d87623589e1ba    20220319           12       18089
# 2      6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3      46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4      37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
# ...                                 ...         ...          ...         ...
# 16828  f35320206f3dd1ffc411e4ac127caf92    20220618           25       18163
# 16829  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16830  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16831  bbcb018f0e5e49e13636f6e78ce9f60f    20220326           13       18163
# 16832  bbcb018f0e5e49e13636f6e78ce9f60f    20220416           16       18163
#
# ...

# %%
query4 = """
SELECT *, wage.wage
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In [37], line 8
#       1 query4 = """
#       2 SELECT *, wage.wage
#       3 FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
#       4 inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
#       5 on wage.uu_id = unem.uu_id
#       6 """
#       7 query_job4 = bigquery_client.query(query4)
# ----> 8 data = query_job4.to_dataframe()
#
# File /opt/homebrew/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1687, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1612 def to_dataframe(
#    1613     self,
#    1614     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1619     geography_as_object: bool = False,
#    1620 ) -> "pandas.DataFrame":
# ...

# %%
wage.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 wage.column
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
wage.columns
# Out:
# Index(['uu_id', 'countyfips', 'tract', 'tract_name', 'average_wage'], dtype='object')

# %%
query4 = """
SELECT *, wage.average_wage
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
query4 = """
SELECT *, wage.countyfips, wage.tract, wage.tract_name, wage.average_wage
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
data
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1      21957d5517323845818d87623589e1ba    20220319           12       18089
# 2      6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3      46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4      37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
# ...                                 ...         ...          ...         ...
# 16828  f35320206f3dd1ffc411e4ac127caf92    20220618           25       18163
# 16829  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16830  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16831  bbcb018f0e5e49e13636f6e78ce9f60f    20220326           13       18163
# 16832  bbcb018f0e5e49e13636f6e78ce9f60f    20220416           16       18163
#
# ...

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
data
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1      21957d5517323845818d87623589e1ba    20220319           12       18089
# 2      6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3      46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4      37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
# ...                                 ...         ...          ...         ...
# 16828  f35320206f3dd1ffc411e4ac127caf92    20220618           25       18163
# 16829  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16830  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16831  bbcb018f0e5e49e13636f6e78ce9f60f    20220326           13       18163
# 16832  bbcb018f0e5e49e13636f6e78ce9f60f    20220416           16       18163
#
# ...

# %%
data = data.drop(data['uu_id_1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [45], line 1
# ----> 1 data = data.drop(data['uu_id_1'])
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
#    (...)
# ...

# %%
data = data.drop('uu_id_1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 data = data.drop('uu_id_1')
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
#    (...)
# ...

# %%
data = data.drop('uu_id_1', axis=1)

# %%
data
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1      21957d5517323845818d87623589e1ba    20220319           12       18089
# 2      6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3      46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4      37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
# ...                                 ...         ...          ...         ...
# 16828  f35320206f3dd1ffc411e4ac127caf92    20220618           25       18163
# 16829  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16830  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16831  bbcb018f0e5e49e13636f6e78ce9f60f    20220326           13       18163
# 16832  bbcb018f0e5e49e13636f6e78ce9f60f    20220416           16       18163
#
# ...

# %%
data.columns
# Out:
# Index(['uu_id', 'timeperiod', 'week_number', 'countyfips', 'tract',
#        'tract_name', 'total_claims', 'edu_8th_or_less', 'edu_grades_9_11',
#        'edu_hs_grad_equiv', 'edu_post_hs', 'edu_unknown',
#        'top_category_employer1', 'top_category_employer2',
#        'top_category_employer3', 'gender_female', 'gender_male', 'gender_na',
#        'race_amerindian', 'race_asian', 'race_black', 'race_noanswer',
#        'race_hawaiiannative', 'race_other', 'race_white', 'countyfips_1',
#        'tract_1', 'tract_name_1', 'average_wage'],
#       dtype='object')

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
data = data.drop('uu_id_1', axis=1)

# %%
data.columns
# Out:
# Index(['uu_id', 'timeperiod', 'week_number', 'countyfips', 'tract',
#        'tract_name', 'total_claims', 'edu_8th_or_less', 'edu_grades_9_11',
#        'edu_hs_grad_equiv', 'edu_post_hs', 'edu_unknown',
#        'top_category_employer1', 'top_category_employer2',
#        'top_category_employer3', 'gender_female', 'gender_male', 'gender_na',
#        'race_amerindian', 'race_asian', 'race_black', 'race_noanswer',
#        'race_hawaiiannative', 'race_other', 'race_white', 'countyfips_1',
#        'tract_1', 'tract_name_1', 'average_wage'],
#       dtype='object')

# %%
data = data.drop(['uu_id_1','countyfips_1','tract_1','tract_name_1'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 data = data.drop(['uu_id_1','countyfips_1','tract_1','tract_name_1'], axis=1)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
dropcol = ['uu_id_1','countyfips_1','tract_1','tract_name_1']
for col in dropcol:
    data = data.drop(col, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [54], line 3
#       1 dropcol = ['uu_id_1','countyfips_1','tract_1','tract_name_1']
#       2 for col in dropcol:
# ----> 3     data = data.drop(col, axis=1)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
query4 = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data` as unem
inner join `ironhacks-data.ironhacks_competition.wage_data` as wage
on wage.uu_id = unem.uu_id
"""
query_job4 = bigquery_client.query(query4)
data = query_job4.to_dataframe()

# %%
dropcol = ['uu_id_1','countyfips_1','tract_1','tract_name_1']
for col in dropcol:
    data = data.drop(col, axis=1)

# %%
data.columns
# Out:
# Index(['uu_id', 'timeperiod', 'week_number', 'countyfips', 'tract',
#        'tract_name', 'total_claims', 'edu_8th_or_less', 'edu_grades_9_11',
#        'edu_hs_grad_equiv', 'edu_post_hs', 'edu_unknown',
#        'top_category_employer1', 'top_category_employer2',
#        'top_category_employer3', 'gender_female', 'gender_male', 'gender_na',
#        'race_amerindian', 'race_asian', 'race_black', 'race_noanswer',
#        'race_hawaiiannative', 'race_other', 'race_white', 'average_wage'],
#       dtype='object')
