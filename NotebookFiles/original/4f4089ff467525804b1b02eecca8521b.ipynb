# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'

# %%
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT * FROM `ironhacks-data.ironhacks_training.weather_data`
"""

# %%
query_job = bigquery_client.query(query)
data = query_job.to_dataframe()
data.head()
# Out:
#          date  max_rel_humidity  max_temperature  mean_temperature  \
# 0  2019-09-04           99.9498          25.4570           18.6242
# 1  2020-02-16           84.4966           8.6228            3.1896
# 2  2019-12-19           95.9017           2.8886           -3.4884
# 3  2020-02-20           70.0359           0.7939           -4.0254
# 4  2019-12-23           97.1634          13.8411            5.7818
#
#    min_rel_humidity  min_temperature  potential_water_deficit  \
# 0           56.4720          11.7913                  -3.6142
# 1           40.7666          -2.2436                  -1.4307
# 2           39.0330          -9.8654                  -0.9389
# 3           34.7544          -8.8446                  -1.4427
# 4           31.2553          -2.2774                  -1.2787
#
#    precipitation_data  wind_speed
# 0                 0.0      3.6461
# 1                 0.0      2.2398
# 2                 0.0      4.1230
# 3                 0.0      4.8531
# 4                 0.0      2.3404

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics
pip install db_dtypes
# Out:
#   File "/var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_2962/3984629028.py", line 6
#     pip install db_dtypes
#         ^
# SyntaxError: invalid syntax

# %%
query = """
SELECT * FROM `ironhacks-data.ironhacks_training.weather_data`
"""

# %%
query_job = bigquery_client.query(query)
data = query_job.to_dataframe()
data.head()
# Out:
#          date  max_rel_humidity  max_temperature  mean_temperature  \
# 0  2019-09-04           99.9498          25.4570           18.6242
# 1  2020-02-16           84.4966           8.6228            3.1896
# 2  2019-12-19           95.9017           2.8886           -3.4884
# 3  2020-02-20           70.0359           0.7939           -4.0254
# 4  2019-12-23           97.1634          13.8411            5.7818
#
#    min_rel_humidity  min_temperature  potential_water_deficit  \
# 0           56.4720          11.7913                  -3.6142
# 1           40.7666          -2.2436                  -1.4307
# 2           39.0330          -9.8654                  -0.9389
# 3           34.7544          -8.8446                  -1.4427
# 4           31.2553          -2.2774                  -1.2787
#
#    precipitation_data  wind_speed
# 0                 0.0      3.6461
# 1                 0.0      2.2398
# 2                 0.0      4.1230
# 3                 0.0      4.8531
# 4                 0.0      2.3404

# %%
import os
import pandas
import db_dtypes
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'

# %%
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT * FROM `ironhacks-data.ironhacks_training.weather_data`
"""

# %%
query_job = bigquery_client.query(query)
data = query_job.to_dataframe()
data.head()
# Out:
#          date  max_rel_humidity  max_temperature  mean_temperature  \
# 0  2019-09-04           99.9498          25.4570           18.6242
# 1  2020-02-16           84.4966           8.6228            3.1896
# 2  2019-12-19           95.9017           2.8886           -3.4884
# 3  2020-02-20           70.0359           0.7939           -4.0254
# 4  2019-12-23           97.1634          13.8411            5.7818
#
#    min_rel_humidity  min_temperature  potential_water_deficit  \
# 0           56.4720          11.7913                  -3.6142
# 1           40.7666          -2.2436                  -1.4307
# 2           39.0330          -9.8654                  -0.9389
# 3           34.7544          -8.8446                  -1.4427
# 4           31.2553          -2.2774                  -1.2787
#
#    precipitation_data  wind_speed
# 0                 0.0      3.6461
# 1                 0.0      2.2398
# 2                 0.0      4.1230
# 3                 0.0      4.8531
# 4                 0.0      2.3404

# %%
import os
import pandas
import db_dtypes
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'

# %%
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT * FROM `ironhacks-data.ironhacks_training.weather_data`
"""

# %%
query_job = bigquery_client.query(query)
data = query_job.to_dataframe()
data.head()
# Out:
#          date  max_rel_humidity  max_temperature  mean_temperature  \
# 0  2019-09-04           99.9498          25.4570           18.6242
# 1  2020-02-16           84.4966           8.6228            3.1896
# 2  2019-12-19           95.9017           2.8886           -3.4884
# 3  2020-02-20           70.0359           0.7939           -4.0254
# 4  2019-12-23           97.1634          13.8411            5.7818
#
#    min_rel_humidity  min_temperature  potential_water_deficit  \
# 0           56.4720          11.7913                  -3.6142
# 1           40.7666          -2.2436                  -1.4307
# 2           39.0330          -9.8654                  -0.9389
# 3           34.7544          -8.8446                  -1.4427
# 4           31.2553          -2.2774                  -1.2787
#
#    precipitation_data  wind_speed
# 0                 0.0      3.6461
# 1                 0.0      2.2398
# 2                 0.0      4.1230
# 3                 0.0      4.8531
# 4                 0.0      2.3404

# %%
import os
import pandas
import db-dtypes
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics
# Out:
#   File "/var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_2962/1473121775.py", line 3
#     import db-dtypes
#              ^
# SyntaxError: invalid syntax

# %%
import os
import pandas
import db_dtypes
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'

# %%
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)

# %%
query = """
SELECT * FROM `ironhacks-data.ironhacks_training.weather_data`
"""

# %%
query_job = bigquery_client.query(query)
data = query_job.to_dataframe()
data.head()
# Out:
#          date  max_rel_humidity  max_temperature  mean_temperature  \
# 0  2019-09-04           99.9498          25.4570           18.6242
# 1  2020-02-16           84.4966           8.6228            3.1896
# 2  2019-12-19           95.9017           2.8886           -3.4884
# 3  2020-02-20           70.0359           0.7939           -4.0254
# 4  2019-12-23           97.1634          13.8411            5.7818
#
#    min_rel_humidity  min_temperature  potential_water_deficit  \
# 0           56.4720          11.7913                  -3.6142
# 1           40.7666          -2.2436                  -1.4307
# 2           39.0330          -9.8654                  -0.9389
# 3           34.7544          -8.8446                  -1.4427
# 4           31.2553          -2.2774                  -1.2787
#
#    precipitation_data  wind_speed
# 0                 0.0      3.6461
# 1                 0.0      2.2398
# 2                 0.0      4.1230
# 3                 0.0      4.8531
# 4                 0.0      2.3404
