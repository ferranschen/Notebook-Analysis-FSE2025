# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1      14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2      f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3      f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4      778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
# ...                                 ...         ...          ...         ...
# 16828  447d5984bb8a8179bff002ccd1bba162    20220910           37       18081
# 16829  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16830  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16831  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
# 16832  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
#
#         tract                                       tract_name  total_claims  \
# 0      950500      Census Tract 9505, Lawrence County, Indiana            10
# 1      110506   Census Tract 1105.06, Hamilton County, Indiana            39
# 2         900            Census Tract 9, Allen County, Indiana            10
# 3       10600           Census Tract 106, Vigo County, Indiana            35
# 4       11200           Census Tract 112, Vigo County, Indiana            37
# ...       ...                                              ...           ...
# 16828  610802    Census Tract 6108.02, Johnson County, Indiana            10
# 16829  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16830  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16831  210603  Census Tract 2106.03, Hendricks County, Indiana            11
# 16832  210603  Census Tract 2106.03, Hendricks County, Indiana            11
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>               <NA>  ...
# 1                 <NA>                0               <NA>  ...
# 2                    0                0               <NA>  ...
# 3                    0             <NA>                 21  ...
# 4                    0             <NA>                 24  ...
# ...                ...              ...                ...  ...
# 16828                0             <NA>               <NA>  ...
# 16829                0             <NA>               <NA>  ...
# 16830                0             <NA>               <NA>  ...
# 16831                0             <NA>               <NA>  ...
# 16832                0             <NA>               <NA>  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1               <NA>         <NA>         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0          0
# 4                 26           11         0               0          0
# ...              ...          ...       ...             ...        ...
# 16828           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16830           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
# 16832           <NA>         <NA>         0               0          0
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0            <NA>              0                    0           0        <NA>
# 1            <NA>           <NA>                    0        <NA>          28
# 2            <NA>              0                    0        <NA>        <NA>
# 3               0           <NA>                    0        <NA>          32
# 4            <NA>           <NA>                    0        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16828           0              0                    0        <NA>        <NA>
# 16829           0              0                    0           0          13
# 16830           0              0                    0           0          13
# 16831        <NA>              0                    0           0        <NA>
# 16832        <NA>              0                    0           0        <NA>
#
# [16833 rows x 25 columns]

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number   f0_
# 0             1   470
# 1             2   498
# 2             3   482
# 3             5   468
# 4             6   455
# 5             7   445
# 6             8   434
# 7             9   420
# 8            10   403
# 9            11   400
# 10           12   390
# 11           13   368
# 12           14   382
# 13           15   420
# 14           16   420
# 15           17   407
# 16           18   397
# 17           19   343
# 18           20   345
# 19           21   350
# 20           22   336
# 21           24   346
# 22           25   371
# 23           26   372
# 24           27   363
# 25           28   258
# 26           29   386
# 27           30   373
# 28           31   405
# 29           32  1158
# 30           33   834
# 31           34   826
# 32           35   806
# 33           36   856
# 34           37   846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) as total_claims
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims
# 0             1           470
# 1             2           498
# 2             3           482
# 3             5           468
# 4             6           455
# 5             7           445
# 6             8           434
# 7             9           420
# 8            10           403
# 9            11           400
# 10           12           390
# 11           13           368
# 12           14           382
# 13           15           420
# 14           16           420
# 15           17           407
# 16           18           397
# 17           19           343
# 18           20           345
# 19           21           350
# 20           22           336
# 21           24           346
# 22           25           371
# 23           26           372
# 24           27           363
# 25           28           258
# 26           29           386
# 27           30           373
# 28           31           405
# 29           32          1158
# 30           33           834
# 31           34           826
# 32           35           806
# 33           36           856
# 34           37           846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT COUNT(total_claims) as total_claims
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     total_claims
# 0            470
# 1            498
# 2            482
# 3            468
# 4            455
# 5            445
# 6            434
# 7            420
# 8            403
# 9            400
# 10           390
# 11           368
# 12           382
# 13           420
# 14           420
# 15           407
# 16           397
# 17           343
# 18           345
# 19           350
# 20           336
# 21           346
# 22           371
# 23           372
# 24           363
# 25           258
# 26           386
# 27           373
# 28           405
# 29          1158
# 30           834
# 31           826
# 32           806
# 33           856
# 34           846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) as total_claims
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims
# 0             1           470
# 1             2           498
# 2             3           482
# 3             5           468
# 4             6           455
# 5             7           445
# 6             8           434
# 7             9           420
# 8            10           403
# 9            11           400
# 10           12           390
# 11           13           368
# 12           14           382
# 13           15           420
# 14           16           420
# 15           17           407
# 16           18           397
# 17           19           343
# 18           20           345
# 19           21           350
# 20           22           336
# 21           24           346
# 22           25           371
# 23           26           372
# 24           27           363
# 25           28           258
# 26           29           386
# 27           30           373
# 28           31           405
# 29           32          1158
# 30           33           834
# 31           34           826
# 32           35           806
# 33           36           856
# 34           37           846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1      14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2      f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3      f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4      778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
# ...                                 ...         ...          ...         ...
# 16828  447d5984bb8a8179bff002ccd1bba162    20220910           37       18081
# 16829  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16830  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16831  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
# 16832  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
#
#         tract                                       tract_name  total_claims  \
# 0      950500      Census Tract 9505, Lawrence County, Indiana            10
# 1      110506   Census Tract 1105.06, Hamilton County, Indiana            39
# 2         900            Census Tract 9, Allen County, Indiana            10
# 3       10600           Census Tract 106, Vigo County, Indiana            35
# 4       11200           Census Tract 112, Vigo County, Indiana            37
# ...       ...                                              ...           ...
# 16828  610802    Census Tract 6108.02, Johnson County, Indiana            10
# 16829  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16830  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16831  210603  Census Tract 2106.03, Hendricks County, Indiana            11
# 16832  210603  Census Tract 2106.03, Hendricks County, Indiana            11
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>               <NA>  ...
# 1                 <NA>                0               <NA>  ...
# 2                    0                0               <NA>  ...
# 3                    0             <NA>                 21  ...
# 4                    0             <NA>                 24  ...
# ...                ...              ...                ...  ...
# 16828                0             <NA>               <NA>  ...
# 16829                0             <NA>               <NA>  ...
# 16830                0             <NA>               <NA>  ...
# 16831                0             <NA>               <NA>  ...
# 16832                0             <NA>               <NA>  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1               <NA>         <NA>         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0          0
# 4                 26           11         0               0          0
# ...              ...          ...       ...             ...        ...
# 16828           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16830           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
# 16832           <NA>         <NA>         0               0          0
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0            <NA>              0                    0           0        <NA>
# 1            <NA>           <NA>                    0        <NA>          28
# 2            <NA>              0                    0        <NA>        <NA>
# 3               0           <NA>                    0        <NA>          32
# 4            <NA>           <NA>                    0        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16828           0              0                    0        <NA>        <NA>
# 16829           0              0                    0           0          13
# 16830           0              0                    0           0          13
# 16831        <NA>              0                    0           0        <NA>
# 16832        <NA>              0                    0           0        <NA>
#
# [16833 rows x 25 columns]

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims
# 0             1           470
# 1             2           498
# 2             3           482
# 3             5           468
# 4             6           455
# 5             7           445
# 6             8           434
# 7             9           420
# 8            10           403
# 9            11           400
# 10           12           390
# 11           13           368
# 12           14           382
# 13           15           420
# 14           16           420
# 15           17           407
# 16           18           397
# 17           19           343
# 18           20           345
# 19           21           350
# 20           22           336
# 21           24           346
# 22           25           371
# 23           26           372
# 24           27           363
# 25           28           258
# 26           29           386
# 27           30           373
# 28           31           405
# 29           32          1158
# 30           33           834
# 31           34           826
# 32           35           806
# 33           36           856
# 34           37           846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

ORDER BY week_number ASC
"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1      14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2      f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3      f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4      778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
# ...                                 ...         ...          ...         ...
# 16828  447d5984bb8a8179bff002ccd1bba162    20220910           37       18081
# 16829  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16830  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16831  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
# 16832  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
#
#         tract                                       tract_name  total_claims  \
# 0      950500      Census Tract 9505, Lawrence County, Indiana            10
# 1      110506   Census Tract 1105.06, Hamilton County, Indiana            39
# 2         900            Census Tract 9, Allen County, Indiana            10
# 3       10600           Census Tract 106, Vigo County, Indiana            35
# 4       11200           Census Tract 112, Vigo County, Indiana            37
# ...       ...                                              ...           ...
# 16828  610802    Census Tract 6108.02, Johnson County, Indiana            10
# 16829  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16830  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16831  210603  Census Tract 2106.03, Hendricks County, Indiana            11
# 16832  210603  Census Tract 2106.03, Hendricks County, Indiana            11
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>               <NA>  ...
# 1                 <NA>                0               <NA>  ...
# 2                    0                0               <NA>  ...
# 3                    0             <NA>                 21  ...
# 4                    0             <NA>                 24  ...
# ...                ...              ...                ...  ...
# 16828                0             <NA>               <NA>  ...
# 16829                0             <NA>               <NA>  ...
# 16830                0             <NA>               <NA>  ...
# 16831                0             <NA>               <NA>  ...
# 16832                0             <NA>               <NA>  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1               <NA>         <NA>         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0          0
# 4                 26           11         0               0          0
# ...              ...          ...       ...             ...        ...
# 16828           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16830           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
# 16832           <NA>         <NA>         0               0          0
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0            <NA>              0                    0           0        <NA>
# 1            <NA>           <NA>                    0        <NA>          28
# 2            <NA>              0                    0        <NA>        <NA>
# 3               0           <NA>                    0        <NA>          32
# 4            <NA>           <NA>                    0        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16828           0              0                    0        <NA>        <NA>
# 16829           0              0                    0           0          13
# 16830           0              0                    0           0          13
# 16831        <NA>              0                    0           0        <NA>
# 16832        <NA>              0                    0           0        <NA>
#
# [16833 rows x 25 columns]

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
LIMIT 1
ORDER BY week_number ASC
"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Syntax error: Expected end of input but got keyword ORDER at [5:1]
#
# Location: US
# Job ID: 241e7579-b024-4e5d-b055-06914f26594c

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

ORDER BY week_number ASC
LIMIT 1
"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  65f24aac652de33abaf3f227b41e2641    20220101            1       18093
#
#     tract                                   tract_name  total_claims  \
# 0  950500  Census Tract 9505, Lawrence County, Indiana            10
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>               <NA>  ...           <NA>
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0        <NA>
#
#    race_noanswer  race_hawaiiannative  race_other  race_white
# 0              0                    0           0        <NA>
#
# [1 rows x 25 columns]

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
DESCRIBE `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Statement not supported: DescribeStatement at [2:1]
#
# Location: US
# Job ID: 90e7a4b3-1d9f-4136-89f8-e38446f11be3

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SHOW COLUMNS 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Statement not supported: ShowStatement at [2:1]
#
# Location: US
# Job ID: 7707b34e-9909-45c3-ace0-4f2dd0f9ee79

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT COLUMNS 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Unrecognized name: COLUMNS at [2:8]
#
# Location: US
# Job ID: 65075795-bbb2-49af-a2ee-9e514703af0f

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SHOW COLUMNS 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Statement not supported: ShowStatement at [2:1]
#
# Location: US
# Job ID: 27c59227-6c93-486f-8b5f-19d1eae52b56

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SHOW COLUMN_NAME 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Statement not supported: ShowStatement at [2:1]
#
# Location: US
# Job ID: d8867437-8a85-4d03-86c3-47837b9e2438

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT COLUMN_NAME 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Unrecognized name: COLUMN_NAME at [2:8]
#
# Location: US
# Job ID: 88c63370-4bc9-4df3-8b96-8dcd87091750

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT COLUMN_NAME 
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = `ironhacks-data.ironhacks_competition.unemployment_data`

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Table "INFORMATION_SCHEMA.COLUMNS" must be qualified with a dataset (e.g. dataset.table).
#
# Location: US
# Job ID: 349f9d26-fc6e-4f67-ad63-e628b3164778

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`

ORDER BY week_number ASC
LIMIT 1

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                               uu_id  timeperiod  week_number  countyfips  \
# 0  65f24aac652de33abaf3f227b41e2641    20220101            1       18093
#
#     tract                                   tract_name  total_claims  \
# 0  950500  Census Tract 9505, Lawrence County, Indiana            10
#
#    edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  gender_female  \
# 0                0             <NA>               <NA>  ...           <NA>
#
#    gender_male gender_na race_amerindian race_asian  race_black  \
# 0         <NA>         0               0          0        <NA>
#
#    race_noanswer  race_hawaiiannative  race_other  race_white
# 0              0                    0           0        <NA>
#
# [1 rows x 25 columns]

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT column_name
FROM `ironhacks-data.ironhacks_competition.INFORMATION_SCHEMA`
WHERE table_name = 'unemployment_data'

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# NotFound: 404 Not found: Table ironhacks-data:ironhacks_competition.INFORMATION_SCHEMA was not found in location US
#
# Location: US
# Job ID: 2c1b7629-ec6c-47fd-9f67-954685b90392

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT column_name
FROM `ironhacks-data.ironhacks_competition.INFORMATION_SCHEMA.TABLES`
WHERE table_name = 'unemployment_data'

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Unrecognized name: column_name at [2:8]
#
# Location: US
# Job ID: ab022afd-6bf2-4d50-b279-3bd4f90ed341

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT column_name
FROM `ironhacks-data.ironhacks_competition.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'unemployment_data'

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                column_name
# 0                    uu_id
# 1               timeperiod
# 2              week_number
# 3               countyfips
# 4                    tract
# 5               tract_name
# 6             total_claims
# 7          edu_8th_or_less
# 8          edu_grades_9_11
# 9        edu_hs_grad_equiv
# 10             edu_post_hs
# 11             edu_unknown
# 12  top_category_employer1
# 13  top_category_employer2
# 14  top_category_employer3
# 15           gender_female
# 16             gender_male
# 17               gender_na
# 18         race_amerindian
# 19              race_asian
# 20              race_black
# 21           race_noanswer
# 22     race_hawaiiannative
# 23              race_other
# 24              race_white

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT column_name
FROM `ironhacks-data.ironhacks_competition.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'unemployment_data'

"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                column_name
# 0                    uu_id
# 1               timeperiod
# 2              week_number
# 3               countyfips
# 4                    tract
# 5               tract_name
# 6             total_claims
# 7          edu_8th_or_less
# 8          edu_grades_9_11
# 9        edu_hs_grad_equiv
# 10             edu_post_hs
# 11             edu_unknown
# 12  top_category_employer1
# 13  top_category_employer2
# 14  top_category_employer3
# 15           gender_female
# 16             gender_male
# 17               gender_na
# 18         race_amerindian
# 19              race_asian
# 20              race_black
# 21           race_noanswer
# 22     race_hawaiiannative
# 23              race_other
# 24              race_white

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %% [markdown]
# SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
# GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Syntax error: Missing whitespace between literal and alias at [2:85]
#
# Location: US
# Job ID: ce04bd45-4519-447e-b50f-b84ba1953985

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, 

FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims
# 0             1           470
# 1             2           498
# 2             3           482
# 3             5           468
# 4             6           455
# 5             7           445
# 6             8           434
# 7             9           420
# 8            10           403
# 9            11           400
# 10           12           390
# 11           13           368
# 12           14           382
# 13           15           420
# 14           16           420
# 15           17           407
# 16           18           397
# 17           19           343
# 18           20           345
# 19           21           350
# 20           22           336
# 21           24           346
# 22           25           371
# 23           26           372
# 24           27           363
# 25           28           258
# 26           29           386
# 27           30           373
# 28           31           405
# 29           32          1158
# 30           33           834
# 31           34           826
# 32           35           806
# 33           36           856
# 34           37           846

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims,
COUNT(edu_8th_or_less) AS 8th

FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Syntax error: Missing whitespace between literal and alias at [3:28]
#
# Location: US
# Job ID: f33c7473-bf54-4806-9e19-371d59d1a6ae

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Syntax error: Missing whitespace between literal and alias at [2:85]
#
# Location: US
# Job ID: ecd94c19-651f-4acb-ba94-da3c5f3486ba

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims  eigth
# 0             1           470    363
# 1             2           498    370
# 2             3           482    378
# 3             5           468    376
# 4             6           455    350
# 5             7           445    359
# 6             8           434    335
# 7             9           420    336
# 8            10           403    325
# 9            11           400    318
# 10           12           390    317
# 11           13           368    309
# 12           14           382    327
# 13           15           420    349
# 14           16           420    356
# 15           17           407    339
# 16           18           397    331
# 17           19           343    297
# 18           20           345    297
# 19           21           350    305
# 20           22           336    293
# 21           24           346    295
# 22           25           371    325
# 23           26           372    323
# 24           27           363    296
# 25           28           258    206
# 26           29           386    319
# 27           30           373    309
# 28           31           405    341
# 29           32          1158    906
# 30           33           834    668
# 31           34           826    684
# 32           35           806    676
# 33           36           856    712
# 34           37           846    658

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims  eigth  nine_eleven
# 0             1           470    363          105
# 1             2           498    370          109
# 2             3           482    378          120
# 3             5           468    376          112
# 4             6           455    350          116
# 5             7           445    359          134
# 6             8           434    335          144
# 7             9           420    336          124
# 8            10           403    325          144
# 9            11           400    318          136
# 10           12           390    317          138
# 11           13           368    309          138
# 12           14           382    327          150
# 13           15           420    349          128
# 14           16           420    356          161
# 15           17           407    339          161
# 16           18           397    331          157
# 17           19           343    297          126
# 18           20           345    297          149
# 19           21           350    305          145
# 20           22           336    293          137
# 21           24           346    295          145
# 22           25           371    325          150
# 23           26           372    323          156
# 24           27           363    296          153
# 25           28           258    206          100
# 26           29           386    319          136
# 27           30           373    309          142
# 28           31           405    341          158
# 29           32          1158    906          390
# 30           33           834    668          274
# 31           34           826    684          322
# 32           35           806    676          318
# 33           36           856    712          324
# 34           37           846    658          340

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims  eigth  nine_eleven  hs_diploma  post_hs  \
# 0             1           470    363          105         204       90
# 1             2           498    370          109         284      126
# 2             3           482    378          120         244      108
# 3             5           468    376          112         233       98
# 4             6           455    350          116         193       94
# 5             7           445    359          134         185       76
# 6             8           434    335          144         192       69
# 7             9           420    336          124         180       73
# 8            10           403    325          144         167       68
# 9            11           400    318          136         171       73
# 10           12           390    317          138         142       65
# 11           13           368    309          138         115       53
# 12           14           382    327          150         122       57
# 13           15           420    349          128         175       90
# 14           16           420    356          161         161       96
# 15           17           407    339          161         142       79
# 16           18           397    331          157         130       89
# 17           19           343    297          126          96       62
# 18           20           345    297          149          87       60
# 19           21           350    305          145          91       75
# 20           22           336    293          137          86       59
# 21           24           346    295          145          87       58
# 22           25           371    325          150          93       82
# 23           26           372    323          156         103       67
# 24           27           363    296          153         114       69
# 25           28           258    206          100          99       31
# 26           29           386    319          136         139       63
# 27           30           373    309          142          97       65
# 28           31           405    341          158         111       70
# 29           32          1158    906          390         345      201
# 30           33           834    668          274         330      168
# 31           34           826    684          322         252      146
# 32           35           806    676          318         254      152
# 33           36           856    712          324         284      206
# 34           37           846    658          340         328      208
#
#     edu_unknown  top_category_employer1  top_category_employer2  \
# 0           341                     470                     470
# 1           331                     498                     498
# 2           338                     482                     482
# 3           339                     468                     468
# 4           331                     455                     455
# 5           323                     445                     445
# 6           338                     434                     434
# 7           315                     420                     420
# 8           295                     403                     403
# 9           306                     400                     400
# 10          307                     390                     390
# 11          290                     368                     368
# 12          292                     382                     382
# 13          296                     420                     420
# 14          291                     420                     420
# 15          286                     407                     407
# 16          289                     397                     397
# 17          250                     343                     343
# 18          243                     345                     345
# 19          255                     350                     350
# 20          242                     336                     336
# 21          247                     346                     346
# 22          271                     371                     371
# 23          274                     372                     372
# 24          255                     363                     363
# 25          190                     258                     258
# 26          273                     386                     386
# 27          259                     373                     373
# 28          281                     405                     405
# 29          807                    1158                    1158
# 30          572                     834                     834
# 31          588                     826                     826
# 32          552                     806                     806
# 33          592                     856                     856
# 34          572                     846                     846
#
#     top_category_employer3  female  male  gender_na  american  asian  black  \
# 0                      470     122   126        446       426    421    202
# 1                      498     203   211        460       433    431    229
# 2                      482     158   166        453       431    426    222
# 3                      468     153   164        441       408    413    198
# 4                      455     115   125        428       412    399    192
# 5                      445      98   105        421       400    394    194
# 6                      434     103   107        411       391    384    195
# 7                      420      95   101        394       383    372    198
# 8                      403      82    87        380       365    366    178
# 9                      400      92   100        375       360    366    186
# 10                     390      68    69        373       354    353    167
# 11                     368      58    62        349       337    339    154
# 12                     382      74    77        364       352    348    163
# 13                     420     108   112        398       387    378    187
# 14                     420      97   104        400       383    371    183
# 15                     407      97   100        384       369    355    181
# 16                     397      93    99        375       369    353    169
# 17                     343      59    57        325       318    304    140
# 18                     345      59    63        332       310    305    143
# 19                     350      66    69        327       321    311    146
# 20                     336      39    42        321       310    297    136
# 21                     346      56    55        329       325    311    129
# 22                     371      78    77        352       345    324    134
# 23                     372      60    63        358       338    329    145
# 24                     363      70    72        350       328    328    129
# 25                     258      58    59        246       237    240    104
# 26                     386      82    81        366       355    337    164
# 27                     373      73    66        347       346    328    156
# 28                     405      68    64        379       376    368    177
# 29                    1158     195   198       1098      1050   1020    477
# 30                     834     234   228        770       758    740    360
# 31                     826     180   170        768       734    740    342
# 32                     806     166   180        742       728    716    328
# 33                     856     210   206        806       784    744    378
# 34                     846     266   266        800       762    728    338
#
#     r_noAns  hawaii  other  white
# 0       227     457    212    211
# 1       275     484    202    242
# 2       285     465    203    205
# 3       289     457    219    199
# 4       286     445    222    193
# 5       279     435    207    178
# 6       266     424    209    192
# 7       261     413    215    175
# 8       256     400    203    158
# 9       245     392    199    156
# 10      253     382    195    129
# 11      243     359    200    135
# 12      259     378    185    134
# 13      280     412    193    171
# 14      284     413    189    157
# 15      272     395    211    133
# 16      252     389    203    139
# 17      228     335    191     98
# 18      242     337    180    112
# 19      226     335    188    107
# 20      219     329    173    113
# 21      213     337    184     96
# 22      204     360    197    127
# 23      216     361    190    127
# 24      216     351    184    151
# 25      150     254    132    101
# 26      223     376    174    133
# 27      226     366    188    113
# 28      245     395    183    135
# 29      579    1134    534    432
# 30      456     818    344    362
# 31      474     806    390    290
# 32      484     780    368    268
# 33      484     826    420    352
# 34      492     826    388    368

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     week_number  total_claims  eigth  nine_eleven  hs_diploma  post_hs  \
# 0             1           470    363          105         204       90
# 1             2           498    370          109         284      126
# 2             3           482    378          120         244      108
# 3             5           468    376          112         233       98
# 4             6           455    350          116         193       94
# 5             7           445    359          134         185       76
# 6             8           434    335          144         192       69
# 7             9           420    336          124         180       73
# 8            10           403    325          144         167       68
# 9            11           400    318          136         171       73
# 10           12           390    317          138         142       65
# 11           13           368    309          138         115       53
# 12           14           382    327          150         122       57
# 13           15           420    349          128         175       90
# 14           16           420    356          161         161       96
# 15           17           407    339          161         142       79
# 16           18           397    331          157         130       89
# 17           19           343    297          126          96       62
# 18           20           345    297          149          87       60
# 19           21           350    305          145          91       75
# 20           22           336    293          137          86       59
# 21           24           346    295          145          87       58
# 22           25           371    325          150          93       82
# 23           26           372    323          156         103       67
# 24           27           363    296          153         114       69
# 25           28           258    206          100          99       31
# 26           29           386    319          136         139       63
# 27           30           373    309          142          97       65
# 28           31           405    341          158         111       70
# 29           32          1158    906          390         345      201
# 30           33           834    668          274         330      168
# 31           34           826    684          322         252      146
# 32           35           806    676          318         254      152
# 33           36           856    712          324         284      206
# 34           37           846    658          340         328      208
#
#     edu_unknown  female  male  gender_na  american  asian  black  r_noAns  \
# 0           341     122   126        446       426    421    202      227
# 1           331     203   211        460       433    431    229      275
# 2           338     158   166        453       431    426    222      285
# 3           339     153   164        441       408    413    198      289
# 4           331     115   125        428       412    399    192      286
# 5           323      98   105        421       400    394    194      279
# 6           338     103   107        411       391    384    195      266
# 7           315      95   101        394       383    372    198      261
# 8           295      82    87        380       365    366    178      256
# 9           306      92   100        375       360    366    186      245
# 10          307      68    69        373       354    353    167      253
# 11          290      58    62        349       337    339    154      243
# 12          292      74    77        364       352    348    163      259
# 13          296     108   112        398       387    378    187      280
# 14          291      97   104        400       383    371    183      284
# 15          286      97   100        384       369    355    181      272
# 16          289      93    99        375       369    353    169      252
# 17          250      59    57        325       318    304    140      228
# 18          243      59    63        332       310    305    143      242
# 19          255      66    69        327       321    311    146      226
# 20          242      39    42        321       310    297    136      219
# 21          247      56    55        329       325    311    129      213
# 22          271      78    77        352       345    324    134      204
# 23          274      60    63        358       338    329    145      216
# 24          255      70    72        350       328    328    129      216
# 25          190      58    59        246       237    240    104      150
# 26          273      82    81        366       355    337    164      223
# 27          259      73    66        347       346    328    156      226
# 28          281      68    64        379       376    368    177      245
# 29          807     195   198       1098      1050   1020    477      579
# 30          572     234   228        770       758    740    360      456
# 31          588     180   170        768       734    740    342      474
# 32          552     166   180        742       728    716    328      484
# 33          592     210   206        806       784    744    378      484
# 34          572     266   266        800       762    728    338      492
#
#     hawaii  other  white
# 0      457    212    211
# 1      484    202    242
# 2      465    203    205
# 3      457    219    199
# 4      445    222    193
# 5      435    207    178
# 6      424    209    192
# 7      413    215    175
# 8      400    203    158
# 9      392    199    156
# 10     382    195    129
# 11     359    200    135
# 12     378    185    134
# 13     412    193    171
# 14     413    189    157
# 15     395    211    133
# 16     389    203    139
# 17     335    191     98
# 18     337    180    112
# 19     335    188    107
# 20     329    173    113
# 21     337    184     96
# 22     360    197    127
# 23     361    190    127
# 24     351    184    151
# 25     254    132    101
# 26     376    174    133
# 27     366    188    113
# 28     395    183    135
# 29    1134    534    432
# 30     818    344    362
# 31     806    390    290
# 32     780    368    268
# 33     826    420    352
# 34     826    388    368

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
data.plot(subplots=True, figsize=(20,24))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/3388555930.py in <module>
#       2 query_job = bigquery_client.query(query)
#       3 unemployment_data = query_job.to_dataframe()
# ----> 4 data.plot(subplots=True, figsize=(20,24))
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.plot(subplots=True, figsize=(20,24))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.cor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/402490999.py in <module>
#       2 query_job = bigquery_client.query(query)
#       3 unemployment_data = query_job.to_dataframe()
# ----> 4 unemployment_data.cor()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cor'

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.corr()
# Out:
#               week_number  total_claims     eigth  nine_eleven  hs_diploma  \
# week_number      1.000000      0.461213  0.511090     0.698389    0.089887
# total_claims     0.461213      1.000000  0.995349     0.928017    0.871190
# eigth            0.511090      0.995349  1.000000     0.948876    0.833268
# nine_eleven      0.698389      0.928017  0.948876     1.000000    0.669371
# hs_diploma       0.089887      0.871190  0.833268     0.669371    1.000000
# post_hs          0.411747      0.942652  0.935534     0.864902    0.891678
# edu_unknown      0.433154      0.996197  0.991225     0.922032    0.864269
# female           0.215849      0.850785  0.822121     0.698628    0.959501
# male             0.160766      0.836276  0.805045     0.671639    0.966196
# gender_na        0.461010      0.999582  0.994607     0.929033    0.867215
# american         0.478258      0.999316  0.996242     0.933477    0.859407
# asian            0.460783      0.999275  0.995219     0.927986    0.866618
# black            0.387556      0.990527  0.981877     0.891319    0.903375
# r_noAns          0.459490      0.980432  0.983377     0.937302    0.852742
# hawaii           0.458927      0.999854  0.994704     0.927065    0.871678
# other            0.500627      0.985220  0.988070     0.949855    0.802809
# white            0.315510      0.961786  0.938738     0.829628    0.951391
#
#                post_hs  edu_unknown    female      male  gender_na  american  \
# week_number   0.411747     0.433154  0.215849  0.160766   0.461010  0.478258
# total_claims  0.942652     0.996197  0.850785  0.836276   0.999582  0.999316
# eigth         0.935534     0.991225  0.822121  0.805045   0.994607  0.996242
# nine_eleven   0.864902     0.922032  0.698628  0.671639   0.929033  0.933477
# hs_diploma    0.891678     0.864269  0.959501  0.966196   0.867215  0.859407
# post_hs       1.000000     0.923521  0.930580  0.920096   0.941443  0.940727
# edu_unknown   0.923521     1.000000  0.830080  0.816155   0.996336  0.995477
# female        0.930580     0.830080  1.000000  0.995991   0.845170  0.840113
# male          0.920096     0.816155  0.995991  1.000000   0.830652  0.824324
# gender_na     0.941443     0.996336  0.845170  0.830652   1.000000  0.999123
# american      0.940727     0.995477  0.840113  0.824324   0.999123  1.000000
# asian         0.933365     0.997070  0.841313  0.826610   0.998660  0.998646
# black         0.941080     0.988255  0.870076  0.858145   0.988869  0.988826
# r_noAns       0.936773     0.976602  0.842401  0.831378   0.978799  0.979232
# hawaii        0.940120     0.996432  0.849412  0.834805   0.999511  0.999196
# other         0.919048     0.987182  0.786626  0.769645   0.986664  0.986820
# white         0.952137     0.955999  0.928915  0.920649   0.961409  0.957149
#
#                  asian     black   r_noAns    hawaii     other     white
# week_number   0.460783  0.387556  0.459490  0.458927  0.500627  0.315510
# total_claims  0.999275  0.990527  0.980432  0.999854  0.985220  0.961786
# eigth         0.995219  0.981877  0.983377  0.994704  0.988070  0.938738
# nine_eleven   0.927986  0.891319  0.937302  0.927065  0.949855  0.829628
# hs_diploma    0.866618  0.903375  0.852742  0.871678  0.802809  0.951391
# post_hs       0.933365  0.941080  0.936773  0.940120  0.919048  0.952137
# edu_unknown   0.997070  0.988255  0.976602  0.996432  0.987182  0.955999
# female        0.841313  0.870076  0.842401  0.849412  0.786626  0.928915
# male          0.826610  0.858145  0.831378  0.834805  0.769645  0.920649
# gender_na     0.998660  0.988869  0.978799  0.999511  0.986664  0.961409
# american      0.998646  0.988826  0.979232  0.999196  0.986820  0.957149
# asian         1.000000  0.989866  0.979498  0.999331  0.984454  0.958174
# black         0.989866  1.000000  0.974833  0.990538  0.967537  0.968916
# r_noAns       0.979498  0.974833  1.000000  0.980270  0.971478  0.932739
# hawaii        0.999331  0.990538  0.980270  1.000000  0.984614  0.962011
# other         0.984454  0.967537  0.971478  0.984614  1.000000  0.923359
# white         0.958174  0.968916  0.932739  0.962011  0.923359  1.000000

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.plot(subplots=True, figsize=(20,24))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.corr()
# Out:
#               week_number  total_claims     eigth  nine_eleven  hs_diploma  \
# week_number      1.000000      0.461213  0.511090     0.698389    0.089887
# total_claims     0.461213      1.000000  0.995349     0.928017    0.871190
# eigth            0.511090      0.995349  1.000000     0.948876    0.833268
# nine_eleven      0.698389      0.928017  0.948876     1.000000    0.669371
# hs_diploma       0.089887      0.871190  0.833268     0.669371    1.000000
# post_hs          0.411747      0.942652  0.935534     0.864902    0.891678
# edu_unknown      0.433154      0.996197  0.991225     0.922032    0.864269
# female           0.215849      0.850785  0.822121     0.698628    0.959501
# male             0.160766      0.836276  0.805045     0.671639    0.966196
# gender_na        0.461010      0.999582  0.994607     0.929033    0.867215
# american         0.478258      0.999316  0.996242     0.933477    0.859407
# asian            0.460783      0.999275  0.995219     0.927986    0.866618
# black            0.387556      0.990527  0.981877     0.891319    0.903375
# r_noAns          0.459490      0.980432  0.983377     0.937302    0.852742
# hawaii           0.458927      0.999854  0.994704     0.927065    0.871678
# other            0.500627      0.985220  0.988070     0.949855    0.802809
# white            0.315510      0.961786  0.938738     0.829628    0.951391
#
#                post_hs  edu_unknown    female      male  gender_na  american  \
# week_number   0.411747     0.433154  0.215849  0.160766   0.461010  0.478258
# total_claims  0.942652     0.996197  0.850785  0.836276   0.999582  0.999316
# eigth         0.935534     0.991225  0.822121  0.805045   0.994607  0.996242
# nine_eleven   0.864902     0.922032  0.698628  0.671639   0.929033  0.933477
# hs_diploma    0.891678     0.864269  0.959501  0.966196   0.867215  0.859407
# post_hs       1.000000     0.923521  0.930580  0.920096   0.941443  0.940727
# edu_unknown   0.923521     1.000000  0.830080  0.816155   0.996336  0.995477
# female        0.930580     0.830080  1.000000  0.995991   0.845170  0.840113
# male          0.920096     0.816155  0.995991  1.000000   0.830652  0.824324
# gender_na     0.941443     0.996336  0.845170  0.830652   1.000000  0.999123
# american      0.940727     0.995477  0.840113  0.824324   0.999123  1.000000
# asian         0.933365     0.997070  0.841313  0.826610   0.998660  0.998646
# black         0.941080     0.988255  0.870076  0.858145   0.988869  0.988826
# r_noAns       0.936773     0.976602  0.842401  0.831378   0.978799  0.979232
# hawaii        0.940120     0.996432  0.849412  0.834805   0.999511  0.999196
# other         0.919048     0.987182  0.786626  0.769645   0.986664  0.986820
# white         0.952137     0.955999  0.928915  0.920649   0.961409  0.957149
#
#                  asian     black   r_noAns    hawaii     other     white
# week_number   0.460783  0.387556  0.459490  0.458927  0.500627  0.315510
# total_claims  0.999275  0.990527  0.980432  0.999854  0.985220  0.961786
# eigth         0.995219  0.981877  0.983377  0.994704  0.988070  0.938738
# nine_eleven   0.927986  0.891319  0.937302  0.927065  0.949855  0.829628
# hs_diploma    0.866618  0.903375  0.852742  0.871678  0.802809  0.951391
# post_hs       0.933365  0.941080  0.936773  0.940120  0.919048  0.952137
# edu_unknown   0.997070  0.988255  0.976602  0.996432  0.987182  0.955999
# female        0.841313  0.870076  0.842401  0.849412  0.786626  0.928915
# male          0.826610  0.858145  0.831378  0.834805  0.769645  0.920649
# gender_na     0.998660  0.988869  0.978799  0.999511  0.986664  0.961409
# american      0.998646  0.988826  0.979232  0.999196  0.986820  0.957149
# asian         1.000000  0.989866  0.979498  0.999331  0.984454  0.958174
# black         0.989866  1.000000  0.974833  0.990538  0.967537  0.968916
# r_noAns       0.979498  0.974833  1.000000  0.980270  0.971478  0.932739
# hawaii        0.999331  0.990538  0.980270  1.000000  0.984614  0.962011
# other         0.984454  0.967537  0.971478  0.984614  1.000000  0.923359
# white         0.958174  0.968916  0.932739  0.962011  0.923359  1.000000

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
cor = unemployment_data.corr()
cor_target = abs(cor["total_claims"])
relevant_features = cor_target[cor_target>0.5]
print(relevant_features)
# Out:
# total_claims    1.000000
# eigth           0.995349
# nine_eleven     0.928017
# hs_diploma      0.871190
# post_hs         0.942652
# edu_unknown     0.996197
# female          0.850785
# male            0.836276
# gender_na       0.999582
# american        0.999316
# asian           0.999275
# black           0.990527
# r_noAns         0.980432
# hawaii          0.999854
# other           0.985220
# white           0.961786
# Name: total_claims, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
cor = unemployment_data.corr()
cor_target = abs(cor["total_claims"])
relevant_features = cor_target[cor_target>0.9]
print(relevant_features)
# Out:
# total_claims    1.000000
# eigth           0.995349
# nine_eleven     0.928017
# post_hs         0.942652
# edu_unknown     0.996197
# gender_na       0.999582
# american        0.999316
# asian           0.999275
# black           0.990527
# r_noAns         0.980432
# hawaii          0.999854
# other           0.985220
# white           0.961786
# Name: total_claims, dtype: float64

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
GROUP BY week_number
ORDER BY week_number ASC
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1986937617.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Unrecognized name: week_number at [4:10]
#
# Location: US
# Job ID: d1b6e0d4-f091-4f5d-bae5-df21673fef6d

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`

"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                 uu_id  countyfips   tract  \
# 0    585f8731c2255d6b3f817a31180848b9       18177     200
# 1    8c9d2aa90948679972a9382aadcc6001       18177     900
# 2    0f3d45341a5b113b813ffb7be7f58bab       18183   50300
# 3    fb55464f8e34af6d750d06968bf719b8       18183   50400
# 4    983badfd7b568728e39a2344a9006078       18001   30200
# ..                                ...         ...     ...
# 520  4a6ae3b5be1b9b7c10c177e1b9fded82       18169  102800
# 521  e0e676badd59e9b1f2ecf853d2ca1ecb       18173   30500
# 522  4338a76c28b57d89da8a28cf06adcf73       18173   30600
# 523  3224483a60925de51923d51b10a00141       18173   30800
# 524  7b67eb2512a721025efe5cb967a38aff       18173   30400
#
#                                     tract_name  average_wage
# 0        Census Tract 2, Wayne County, Indiana   6612.000000
# 1        Census Tract 9, Wayne County, Indiana   9883.250000
# 2    Census Tract 503, Whitley County, Indiana  13992.250000
# 3    Census Tract 504, Whitley County, Indiana  13613.500000
# 4      Census Tract 302, Adams County, Indiana  11816.666667
# ..                                         ...           ...
# 520  Census Tract 1028, Wabash County, Indiana   7061.200000
# 521  Census Tract 305, Warrick County, Indiana   8687.000000
# 522  Census Tract 306, Warrick County, Indiana  11917.375000
# 523  Census Tract 308, Warrick County, Indiana  15117.700000
# 524  Census Tract 304, Warrick County, Indiana   9386.000000
#
# [525 rows x 5 columns]

# %%
query = """
SELECT column_name
FROM `ironhacks-data.ironhacks_competition.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'wage_data'
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#     column_name
# 0         uu_id
# 1    countyfips
# 2         tract
# 3    tract_name
# 4  average_wage

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.plot(subplots=True, figsize=(20,24))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      f013068de98db1470bd986137a0c6d23    20220416           16       18003
# 1      21957d5517323845818d87623589e1ba    20220319           12       18089
# 2      6a5609f385912113b6f1014b958ed748    20220326           13       18089
# 3      46b2882ec4c373527ec33f7bd4f1388d    20220716           29       18089
# 4      37495d17e82f7df326bfc2c4c090f7b7    20220409           15       18089
# ...                                 ...         ...          ...         ...
# 16828  f35320206f3dd1ffc411e4ac127caf92    20220618           25       18163
# 16829  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16830  f35320206f3dd1ffc411e4ac127caf92    20220827           35       18163
# 16831  bbcb018f0e5e49e13636f6e78ce9f60f    20220326           13       18163
# 16832  bbcb018f0e5e49e13636f6e78ce9f60f    20220416           16       18163
#
#        tract                                        tract_name  total_claims  \
# 0        900             Census Tract 9, Allen County, Indiana            22
# 1      10400            Census Tract 104, Lake County, Indiana           111
# 2      11500            Census Tract 115, Lake County, Indiana            39
# 3      20700            Census Tract 207, Lake County, Indiana            14
# 4      21900            Census Tract 219, Lake County, Indiana           155
# ...      ...                                               ...           ...
# 16828   3804   Census Tract 38.04, Vanderburgh County, Indiana            21
# 16829   3804   Census Tract 38.04, Vanderburgh County, Indiana            22
# 16830   3804   Census Tract 38.04, Vanderburgh County, Indiana            22
# 16831  10203  Census Tract 102.03, Vanderburgh County, Indiana            53
# 16832  10203  Census Tract 102.03, Vanderburgh County, Indiana            24
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>                 14  ...
# 1                    0             <NA>                108  ...
# 2                    0             <NA>               <NA>  ...
# 3                    0             <NA>               <NA>  ...
# 4                    0             <NA>                 69  ...
# ...                ...              ...                ...  ...
# 16828                0             <NA>               <NA>  ...
# 16829                0             <NA>                 13  ...
# 16830                0             <NA>                 13  ...
# 16831                0             <NA>                 48  ...
# 16832                0             <NA>                 18  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1                 76           35         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0       <NA>
# 4                 90           65         0               0          0
# ...              ...          ...       ...             ...        ...
# 16828           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16830           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
# 16832             11           13         0               0       <NA>
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0              11              0                    0        <NA>        <NA>
# 1            <NA>           <NA>                    0           0           0
# 2              39              0                    0           0           0
# 3              10              0                    0        <NA>        <NA>
# 4             135           <NA>                 <NA>        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16828        <NA>           <NA>                    0        <NA>          14
# 16829        <NA>           <NA>                    0        <NA>        <NA>
# 16830        <NA>           <NA>                    0        <NA>        <NA>
# 16831        <NA>           <NA>                    0           0        <NA>
# 16832        <NA>           <NA>                    0           0        <NA>
#
# [16833 rows x 25 columns]

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1      14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2      f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3      f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4      778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
# ...                                 ...         ...          ...         ...
# 16828  447d5984bb8a8179bff002ccd1bba162    20220910           37       18081
# 16829  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16830  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16831  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
# 16832  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
#
#         tract                                       tract_name  total_claims  \
# 0      950500      Census Tract 9505, Lawrence County, Indiana            10
# 1      110506   Census Tract 1105.06, Hamilton County, Indiana            39
# 2         900            Census Tract 9, Allen County, Indiana            10
# 3       10600           Census Tract 106, Vigo County, Indiana            35
# 4       11200           Census Tract 112, Vigo County, Indiana            37
# ...       ...                                              ...           ...
# 16828  610802    Census Tract 6108.02, Johnson County, Indiana            10
# 16829  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16830  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16831  210603  Census Tract 2106.03, Hendricks County, Indiana            11
# 16832  210603  Census Tract 2106.03, Hendricks County, Indiana            11
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>               <NA>  ...
# 1                 <NA>                0               <NA>  ...
# 2                    0                0               <NA>  ...
# 3                    0             <NA>                 21  ...
# 4                    0             <NA>                 24  ...
# ...                ...              ...                ...  ...
# 16828                0             <NA>               <NA>  ...
# 16829                0             <NA>               <NA>  ...
# 16830                0             <NA>               <NA>  ...
# 16831                0             <NA>               <NA>  ...
# 16832                0             <NA>               <NA>  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1               <NA>         <NA>         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0          0
# 4                 26           11         0               0          0
# ...              ...          ...       ...             ...        ...
# 16828           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16830           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
# 16832           <NA>         <NA>         0               0          0
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0            <NA>              0                    0           0        <NA>
# 1            <NA>           <NA>                    0        <NA>          28
# 2            <NA>              0                    0        <NA>        <NA>
# 3               0           <NA>                    0        <NA>          32
# 4            <NA>           <NA>                    0        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16828           0              0                    0        <NA>        <NA>
# 16829           0              0                    0           0          13
# 16830           0              0                    0           0          13
# 16831        <NA>              0                    0           0        <NA>
# 16832        <NA>              0                    0           0        <NA>
#
# [16833 rows x 25 columns]

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
print(unemployment_data)
# Out:
#                                   uu_id  timeperiod  week_number  countyfips  \
# 0      65f24aac652de33abaf3f227b41e2641    20220101            1       18093
# 1      14ceb8012cb1b912044297c8933cfcfc    20220101            1       18057
# 2      f013068de98db1470bd986137a0c6d23    20220101            1       18003
# 3      f70960d492c2fd067680a14baa0f66e9    20220101            1       18167
# 4      778946d9696cd6c95f57e8b1e6336389    20220101            1       18167
# ...                                 ...         ...          ...         ...
# 16823  1ec881fbb0021331b2b29c95049284fb    20220910           37       18097
# 16825  7f9c903be0e820137bd63ee9e9a97af8    20220910           37       18097
# 16827  447d5984bb8a8179bff002ccd1bba162    20220910           37       18081
# 16829  7dd5fff353cd08adc694aa74d7fa31af    20220910           37       18063
# 16831  06c78e49b4daedfeb808c42e58fb25e4    20220910           37       18063
#
#         tract                                       tract_name  total_claims  \
# 0      950500      Census Tract 9505, Lawrence County, Indiana            10
# 1      110506   Census Tract 1105.06, Hamilton County, Indiana            39
# 2         900            Census Tract 9, Allen County, Indiana            10
# 3       10600           Census Tract 106, Vigo County, Indiana            35
# 4       11200           Census Tract 112, Vigo County, Indiana            37
# ...       ...                                              ...           ...
# 16823  360201     Census Tract 3602.01, Marion County, Indiana            30
# 16825  380403     Census Tract 3804.03, Marion County, Indiana            14
# 16827  610802    Census Tract 6108.02, Johnson County, Indiana            10
# 16829  210202  Census Tract 2102.02, Hendricks County, Indiana            13
# 16831  210603  Census Tract 2106.03, Hendricks County, Indiana            11
#
#        edu_8th_or_less  edu_grades_9_11  edu_hs_grad_equiv  ...  \
# 0                    0             <NA>               <NA>  ...
# 1                 <NA>                0               <NA>  ...
# 2                    0                0               <NA>  ...
# 3                    0             <NA>                 21  ...
# 4                    0             <NA>                 24  ...
# ...                ...              ...                ...  ...
# 16823                0             <NA>                 20  ...
# 16825                0             <NA>               <NA>  ...
# 16827                0             <NA>               <NA>  ...
# 16829                0             <NA>               <NA>  ...
# 16831                0             <NA>               <NA>  ...
#
#        gender_female  gender_male gender_na race_amerindian race_asian  \
# 0               <NA>         <NA>         0               0          0
# 1               <NA>         <NA>         0               0          0
# 2               <NA>         <NA>         0               0          0
# 3               <NA>         <NA>         0               0          0
# 4                 26           11         0               0          0
# ...              ...          ...       ...             ...        ...
# 16823             10           20         0               0          0
# 16825           <NA>         <NA>         0               0          0
# 16827           <NA>         <NA>         0               0          0
# 16829           <NA>         <NA>         0               0          0
# 16831           <NA>         <NA>         0               0          0
#
#        race_black  race_noanswer  race_hawaiiannative  race_other  race_white
# 0            <NA>              0                    0           0        <NA>
# 1            <NA>           <NA>                    0        <NA>          28
# 2            <NA>              0                    0        <NA>        <NA>
# 3               0           <NA>                    0        <NA>          32
# 4            <NA>           <NA>                    0        <NA>        <NA>
# ...           ...            ...                  ...         ...         ...
# 16823          25              0                    0        <NA>        <NA>
# 16825           0              0                    0        <NA>        <NA>
# 16827           0              0                    0        <NA>        <NA>
# 16829           0              0                    0           0          13
# 16831        <NA>              0                    0           0        <NA>
#
# [13977 rows x 25 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
unemployment_data.plot(subplots=True, figsize=(20,24))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
#unemployment_data.plot(subplots=True, figsize=(20,24))
cor_target = abs(cor["total_claims"])
relevant_features = cor_target[cor_target>0.8]
print(relevant_features)
# Out:
# total_claims    1.000000
# eigth           0.995349
# nine_eleven     0.928017
# hs_diploma      0.871190
# post_hs         0.942652
# edu_unknown     0.996197
# female          0.850785
# male            0.836276
# gender_na       0.999582
# american        0.999316
# asian           0.999275
# black           0.990527
# r_noAns         0.980432
# hawaii          0.999854
# other           0.985220
# white           0.961786
# Name: total_claims, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import os
import pandas
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import magics

# %%
BIGQUERY_PROJECT = 'ironhacks-data'
bigquery_client = bigquery.Client(project=BIGQUERY_PROJECT)
query = """
SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS eigth, COUNT(edu_grades_9_11) AS nine_eleven, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY week_number
ORDER BY week_number ASC
"""
#
#SELECT week_number, COUNT(total_claims) AS total_claims, COUNT(edu_8th_or_less) AS 8th, COUNT(edu_grades_9_11) AS 9_11, COUNT(edu_hs_grad_equiv) AS hs_diploma, COUNT(edu_post_hs) AS post_hs, COUNT(edu_unknown) AS edu_unknown, COUNT(top_category_employer1) AS top_category_employer1, COUNT(top_category_employer2) AS top_category_employer2, COUNT(top_category_employer3) AS top_category_employer3, COUNT(gender_female) AS female, COUNT(gender_male) AS male, COUNT(gender_na) AS gender_na, COUNT(race_amerindian) AS american, COUNT(race_asian) AS asian, COUNT(race_black) AS black, COUNT(race_noanswer) AS r_noAns, COUNT(race_hawaiiannative) AS hawaii, COUNT(race_other) AS other, COUNT(race_white) AS white
#GROUP BY week_number

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
#unemployment_data.plot(subplots=True, figsize=(20,24))
cor_target = abs(cor["total_claims"])
relevant_features = cor_target[cor_target>0.9]
print(relevant_features)
# Out:
# total_claims    1.000000
# eigth           0.995349
# nine_eleven     0.928017
# post_hs         0.942652
# edu_unknown     0.996197
# gender_na       0.999582
# american        0.999316
# asian           0.999275
# black           0.990527
# r_noAns         0.980432
# hawaii          0.999854
# other           0.985220
# white           0.961786
# Name: total_claims, dtype: float64

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
WHERE table_name = 'wage_data'
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
wage_data = query_job.to_dataframe()
print(wage_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/3210117505.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 wage_data = query_job.to_dataframe()
#       4 print(wage_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Unrecognized name: table_name; Did you mean tract_name? at [4:7]
#
# Location: US
# Job ID: 8f0e4d48-a31a-48d3-9ee9-76dc414e9aa4

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.wage_data`
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
wage_data = query_job.to_dataframe()
print(wage_data)
# Out:
#                                 uu_id  countyfips   tract  \
# 0    585f8731c2255d6b3f817a31180848b9       18177     200
# 1    8c9d2aa90948679972a9382aadcc6001       18177     900
# 2    0f3d45341a5b113b813ffb7be7f58bab       18183   50300
# 3    fb55464f8e34af6d750d06968bf719b8       18183   50400
# 4    983badfd7b568728e39a2344a9006078       18001   30200
# ..                                ...         ...     ...
# 520  4a6ae3b5be1b9b7c10c177e1b9fded82       18169  102800
# 521  e0e676badd59e9b1f2ecf853d2ca1ecb       18173   30500
# 522  4338a76c28b57d89da8a28cf06adcf73       18173   30600
# 523  3224483a60925de51923d51b10a00141       18173   30800
# 524  7b67eb2512a721025efe5cb967a38aff       18173   30400
#
#                                     tract_name  average_wage
# 0        Census Tract 2, Wayne County, Indiana   6612.000000
# 1        Census Tract 9, Wayne County, Indiana   9883.250000
# 2    Census Tract 503, Whitley County, Indiana  13992.250000
# 3    Census Tract 504, Whitley County, Indiana  13613.500000
# 4      Census Tract 302, Adams County, Indiana  11816.666667
# ..                                         ...           ...
# 520  Census Tract 1028, Wabash County, Indiana   7061.200000
# 521  Census Tract 305, Warrick County, Indiana   8687.000000
# 522  Census Tract 306, Warrick County, Indiana  11917.375000
# 523  Census Tract 308, Warrick County, Indiana  15117.700000
# 524  Census Tract 304, Warrick County, Indiana   9386.000000
#
# [525 rows x 5 columns]

# %%
query = """
SELECT tract_name
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
print(unemployment_data)
# Out:
#                                            tract_name
# 0         Census Tract 9505, Lawrence County, Indiana
# 1      Census Tract 1105.06, Hamilton County, Indiana
# 2               Census Tract 9, Allen County, Indiana
# 3              Census Tract 106, Vigo County, Indiana
# 4              Census Tract 112, Vigo County, Indiana
# ...                                               ...
# 4841       Census Tract 204, Marshall County, Indiana
# 8067     Census Tract 9619, Kosciusko County, Indiana
# 9181   Census Tract 9704.02, LaGrange County, Indiana
# 9817      Census Tract 9706, LaGrange County, Indiana
# 11131   Census Tract 201.02, Marshall County, Indiana
#
# [525 rows x 1 columns]

# %%
query = """
SELECT week_number, tract_name, COUNT(total_claims) AS total_claims
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY tract_name
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1681079503.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 unemployment_data.drop_duplicates(inplace = True)
#       5 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 SELECT list expression references column week_number which is neither grouped nor aggregated at [2:8]
#
# Location: US
# Job ID: 01494f07-391f-44ed-b742-a7fa9aabfe0e

# %%
query = """
SELECT week_number, 
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY tract_name
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1681079503.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 unemployment_data.drop_duplicates(inplace = True)
#       5 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 SELECT list expression references column week_number which is neither grouped nor aggregated at [2:8]
#
# Location: US
# Job ID: b29965e4-8669-4da6-bd24-cc45ac7cfd97

# %%
query = """
SELECT *
FROM `ironhacks-data.ironhacks_competition.unemployment_data`
GROUP BY tract_name
ORDER BY week_number 
"""

# %%
# QUERY THE DATA ONCE
query_job = bigquery_client.query(query)
unemployment_data = query_job.to_dataframe()
unemployment_data.drop_duplicates(inplace = True)
print(unemployment_data)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/l2/cnhff0_n1470l4xf0p7v7l_40000gn/T/ipykernel_4650/1681079503.py in <module>
#       1 # QUERY THE DATA ONCE
#       2 query_job = bigquery_client.query(query)
# ----> 3 unemployment_data = query_job.to_dataframe()
#       4 unemployment_data.drop_duplicates(inplace = True)
#       5 print(unemployment_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1685                 :mod:`shapely` library cannot be imported.
#    1686         """
# -> 1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     102     )
#     103     if progress_bar is None:
# --> 104         return query_job.result(max_results=max_results)
#     105
#     106     i = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497                 do_get_result = job_retry(do_get_result)
#    1498
# -> 1499             do_get_result()
#    1500
#    1501         except exceptions.GoogleAPICallError as exc:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1487                     self._job_retry = job_retry
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#    1491                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     726
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#     730     def cancelled(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# BadRequest: 400 Star expansion expression references column uu_id which is neither grouped nor aggregated at [2:8]
#
# Location: US
# Job ID: e74a3b02-da23-4943-8ce4-ae30c12328c5
